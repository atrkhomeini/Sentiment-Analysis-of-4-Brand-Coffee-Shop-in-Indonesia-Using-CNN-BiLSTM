# %% [markdown]
# ASPECT EXTRACTION

# %%
import yaml

# Load API key from the YAML file
with open('../key/key.yml', 'r') as file:
    keys = yaml.safe_load(file)
    GEMINI_API_KEY = keys.get('GEMINI_API_KEY')

print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %%
import pandas as pd
import google.generativeai as genai
import time
import json
import os

# %%
# Ensure the client and model are correctly initialized
client = genai.configure(api_key=GEMINI_API_KEY)

# Inisialisasi model Gemini
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
df = pd.read_excel('../data/output/df_test.xlsx',sheet_name='Sheet1')
# Siapkan kolom hasil
if 'Predicted_Aspects' not in df.columns:
    df['Predicted_Aspects'] = ""
if 'Predicted_Keywords' not in df.columns:
    df['Predicted_Keywords'] = ""

# %%
df
# Out:
#         Date                                               Text  \
# 0    04/2024                              tuku, fore, tomoro si
# 1    04/2024                                Tukuuu > soe > fore
# 2    09/2024  tergantung kondisi dompet, kalo lagi kaya fore...
# 3    12/2024  Cafe malt latte plis, itu dah khas bgt klo di ...
# 4    08/2024  bday upsize kakk.. download fore B04ECD pake k...
# ..       ...                                                ...
# 451  04/2024  kalo berdasarkan yang di pic si aku pilih fore...
# 452  01/2024                             Ini fore atau apa kak?
# 453  04/2024  Point coffee dolce sama fore fav beng beng ga ...
# 454  04/2024                                         tuku, fore
# 455  04/2024                       Tuku, fore, sm kopi kenangan
#
#                                     Text Normalization Brand  Sentimen  \
# 0                                  tuku fore tomoro si  fore  positive
# 1                                      tukuuu soe fore  fore  positive
# 2    tergantung dompet kaya fore kopi kenangan miss...  fore   neutral
# 3    cafe malt latte plis deh khas banget fore gant...  fore  positive
# 4    bday upsize kakk download fore b04ecd pakai ko...  fore   neutral
# ..                                                 ...   ...       ...
# 451                             pic si pilih fore tuku  fore  positive
# 452                                           fore kak  fore  positive
# 453  point coffee coffee dolce fore favorit beng be...  fore  positive
# 454                                          tuku fore  fore  negative
# 455                            tuku fore kopi kenangan  fore  positive
#
#     Predicted_Aspect  Encoded_Label Predicted_Aspects Predicted_Keywords
# 0                NaN              2
# 1                NaN              2
# 2             Produk              1
# 3             Produk              2
# 4            Layanan              1
# ..               ...            ...               ...                ...
# 451           Produk              2
# 452              NaN              2
# 453           Produk              2
# 454           Produk              0
# 455           Produk              2
#
# [456 rows x 9 columns]

# %%
# 2. Checkpoint
checkpoint_file = '../data/output/fore_progress_checkpoint_test.json'
progress = {}
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, 'r') as f:
        progress = json.load(f)

# Looping untuk Zero-Shot Classification
save_interval = 10  # Simpan setiap 10 tweet
counter = 0

# %%
for idx, row in df.iterrows():
    tweet = row['Text']
    # Jika sudah pernah diproses skip
    if str(idx) in progress:
        df.at[idx, 'Predicted_Aspects'] = progress[str(idx)]['aspects']
        df.at[idx, 'Predicted_Keywords'] = progress[str(idx)]['keywords']
        continue
    
    prompt = f"""
    Identifikasi aspek-aspek berikut yang dibahas dalam ulasan Twitter tentang kedai kopi ini: Kualitas Kopi, Layanan Pelanggan, Harga/Nilai, Suasana/Tempat, Menu Lain, Promo. Untuk setiap aspek yang relevan, sebutkan kata-kata kunci terkait. Jika suatu aspek tidak disebutkan, abaikan.
    Sebagai catatan, ketika ulasan mengandung kata 'kopi kenangan', itu berarti merek tersebut sedang dibahas. Jadi itu bukanlah keyword yang relevan untuk aspek-aspek tersebut.
    Ulasan: "{tweet}"

    Format:
    Aspek: [Aspek yang teridentifikasi]
    Kata Kunci: [Kata kunci dari ulasan]"""
    
    try:
        resp = model.generate_content([prompt])
        text = resp.text.strip()

        # --- Parsing sederhana berdasarkan baris “Aspek:” dan “Kata Kunci:” ---
        aspects, keywords = [], []
        for line in text.splitlines():
            if line.lower().startswith("aspek:"):
                aspects.append(line.split(":",1)[1].strip())
            elif line.lower().startswith("kata kunci:"):
                keywords.append(line.split(":",1)[1].strip())

        aspects_str  = "; ".join(aspects)
        keywords_str = "; ".join(keywords)

        df.at[idx, 'Predicted_Aspects']  = aspects_str
        df.at[idx, 'Predicted_Keywords'] = keywords_str
        progress[str(idx)] = {'aspects': aspects_str, 'keywords': keywords_str}
        counter += 1
        print(f"[{idx}] → Aspek: {aspects_str} | Keywords: {keywords_str}")

        # Simpan berkala
        if counter % save_interval == 0:
            with open(checkpoint_file, 'w') as f:
                json.dump(progress, f)
            df.to_excel('fore_tweet_with_predicted_aspect_test.xlsx', index=False)
            print(f"— Saved checkpoint at tweet #{idx}")

        time.sleep(2.0)

    except Exception as e:
        print(f"Error on idx {idx}: {e}")
        df.at[idx, 'Predicted_Aspects']  = 'ERROR'
        df.at[idx, 'Predicted_Keywords'] = ''
        continue

# 4. Final save
with open(checkpoint_file, 'w') as f:
    json.dump(progress, f)
df.to_excel('fore_tweet_with_predicted_aspect_test.xlsx', index=False)
print("✅ Done. All predictions saved.")
# Out:
# [90] → Aspek: Menu Lain | Keywords: matcha fore, enaak, rasanya lucu
# [91] → Aspek: Kualitas Kopi | Keywords: strong, gak strong
# [92] → Aspek: Kualitas Kopi | Keywords: kuat
# [93] → Aspek: Harga/Nilai; Promo | Keywords: point; point
# [94] → Aspek: Kualitas Kopi | Keywords: based kopinya enak, semua varian kopinya enak, enak sih kopi'nya, americanonya kurang banget, varian kopi susunya enak-enak, lumayan sih based kopinya
# [95] → Aspek: Kualitas Kopi; Menu Lain | Keywords: less sugar, manis bgt, powder matcha nya, enak, beda tipe matcha, lebih enak; matcha, powder matcha, less sugar, no sugar
# [96] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: top tier; mahal, ukuran large, ukuran jumbo
# [97] → Aspek: Kualitas Kopi | Keywords: enak bgt, g kuat lambungnya, suka marah, minum kopi
# [98] → Aspek: Kualitas Kopi; Menu Lain | Keywords: americano, enak; matcha, susu oat, matcha oat latte, enak
# [99] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #99
# [100] → Aspek: Menu Lain | Keywords: kemanisan, matchanya
# [101] → Aspek: Menu Lain | Keywords: enaknya, love, matcha, Fore
# [102] → Aspek:  | Keywords:
# [103] → Aspek: Kualitas Kopi | Keywords: Kopsu tetangga, Caramel macchiato, Butterscotch seasalt latte
# [104] → Aspek:  | Keywords:
# [105] → Aspek: Menu Lain | Keywords: junior, belinya
# [106] → Aspek:  | Keywords:
# [107] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: palm sugar latte, buttercream latte, pandan latte; gaada disini; Es.Teh Indonesia, gaada yg cocok
# [108] → Aspek: Menu Lain | Keywords: nonkopi
# [109] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #109
# [110] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: less sugar, ga kemanisan, normal sugarnya, manis bgt; normal ice aja gak penuh, less ice, gak worth it
# [111] → Aspek: Menu Lain | Keywords: butterscotch
# [112] → Aspek: Promo | Keywords: Ultah, klaim, Birthday reward, app fore
# [113] → Aspek: Kualitas Kopi | Keywords: enak
# [114] → Aspek:  | Keywords:
# [115] → Aspek: Menu Lain | Keywords: matcha latte, espresso, wajib cobain
# [116] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enakkk; tempatnya, cozy banget
# [117] → Aspek: Menu Lain | Keywords: butterscotchnya, enak
# [118] → Aspek:  | Keywords:
# [119] → Aspek: Menu Lain | Keywords: muffin cokelat fore, makanan dr surga
# — Saved checkpoint at tweet #119
# [120] → Aspek: Harga/Nilai; Promo | Keywords: mihil; pelit diskon
# [121] → Aspek: Suasana/Tempat | Keywords: kafe, sendiri friendly, sendirian friendly
# [122] → Aspek:  | Keywords:
# [123] → Aspek: Menu Lain | Keywords: non coffe, enakk
# [124] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopi, enak; seasalt, coklat, cheesecream
# [125] → Aspek: Kualitas Kopi | Keywords: terdebest, Tuku, Fore
# [126] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak, buat sendiri, big no, menang manis doang; feel matcha, fore
# [127] → Aspek: Kualitas Kopi | Keywords: seenak itu
# [128] → Aspek:  | Keywords:
# [129] → Aspek: Kualitas Kopi; Menu Lain | Keywords: caramel macchiato; caramel macchiato, MATCHA LATTE, ENAK BGT, PALING ENAKKKK!!!, chizu redvelvet
# — Saved checkpoint at tweet #129
# [130] → Aspek: Menu Lain | Keywords: enak, pandan latte
# [131] → Aspek: Kualitas Kopi | Keywords: best, hot, half sugar, cold, creamy, enak, less sugar, toping seasalt, mantap
# [132] → Aspek: Layanan Pelanggan | Keywords: mau bayar, ga bisa cash
# [133] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: % arabica, the best, kemanisan; PI, dimana-mana
# [134] → Aspek:  | Keywords:
# [135] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: rasanya, seenak; mahal, worth
# [136] → Aspek:  | Keywords:
# [137] → Aspek: Kualitas Kopi; Harga/Nilai; Promo | Keywords: enak bgttt, Butterscotch seasalt Cafe Malt latte, Buttercream Latte; diskon 50%; diskon 50%
# [138] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enaaak, ga konsisten, beda rasa, lumayan strong, hint paitnya dapet, luvs, ga perlu less sugar; Matcha tomoro
# [139] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #139
# [140] → Aspek: Kualitas Kopi; Menu Lain | Keywords: arabica; kopsus duren oat ls
# [141] → Aspek:  | Keywords:
# [142] → Aspek: Kualitas Kopi | Keywords: enak
# [143] → Aspek: Kualitas Kopi | Keywords: minum kopinya fore mules, ngopi sebelum makan fine2 aja
# [144] → Aspek:  | Keywords:
# [145] → Aspek: Kualitas Kopi | Keywords: andalanque
# [146] → Aspek: Suasana/Tempat | Keywords: deket rumah
# [147] → Aspek:  | Keywords:
# [148] → Aspek: Suasana/Tempat | Keywords: tempatku, gada fore
# [149] → Aspek: Kualitas Kopi | Keywords: Nampol pisan, kopi dukun, kopi tubruk, item pekat gitel, turu, cespleng, melek
# — Saved checkpoint at tweet #149
# [150] → Aspek: Harga/Nilai | Keywords: tuku
# [151] → Aspek:  | Keywords:
# [152] → Aspek: Kualitas Kopi; Harga/Nilai; Promo | Keywords: enak; Harganya, ga jauh beda; promo, appsnya
# [153] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: semuanya, enak; di fore; semuanya, enak
# [154] → Aspek: Kualitas Kopi | Keywords: creamynya, suka
# [155] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: enak2, sugar nya gak bisa custom, terlalu manis, suka kopi yg manis; lebih murah
# [156] → Aspek: Kualitas Kopi; Harga/Nilai; Promo | Keywords: Opal Coffee, Fore, favorit, bikin sendiri; lebih mihil, 1 liter, 2 liter, 120rb; promo, dpt 2 liter
# [157] → Aspek: Suasana/Tempat; Menu Lain | Keywords: cafe lokal, daerah lu; jco, roti o
# [158] → Aspek: Kualitas Kopi | Keywords: Arabica
# [159] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #159
# [160] → Aspek:  | Keywords:
# [161] → Aspek: Suasana/Tempat; Menu Lain | Keywords: di fore; Marigume udon, kimukatsu, gokana
# [162] → Aspek:  | Keywords:
# [163] → Aspek: Menu Lain | Keywords: matcha, es teh
# [164] → Aspek: Menu Lain | Keywords: Matcha, aneh, best
# [165] → Aspek: Kualitas Kopi | Keywords: enak
# [166] → Aspek:  | Keywords:
# [167] → Aspek: Kualitas Kopi; Menu Lain | Keywords: caramel macchiato, enak; matcha green tea, classic milo
# [168] → Aspek: Kualitas Kopi | Keywords: arabika, nyobain, tuku, fore, point
# [169] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #169
# [170] → Aspek: Suasana/Tempat | Keywords: skripsian, for life
# [171] → Aspek:  | Keywords:
# [172] → Aspek: Promo; Harga/Nilai | Keywords: Ngandelin promo, bikin 2 akun; lebih hemat lg, bisa bikin sendiri, bubuk kopi indocafe, susu literan
# [173] → Aspek:  | Keywords:
# [174] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kureng, kopinya; varian, hojicha, matcha, enak
# [175] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain; Promo | Keywords: the best, woww, enak banget, nothing spesial, rasanya beda; mahal, murahan; fore butterscotch, point, yg lain, jj; promo
# [176] → Aspek: Kualitas Kopi | Keywords: kaga enak, rasa tepung keset, non sugar, masi enakan, fore, sbux, nuju
# [177] → Aspek: Harga/Nilai; Promo | Keywords: disc 50%, max 20k; Apk fore nya, khusus member baru, disc 50%, max 20k
# [178] → Aspek:  | Keywords:
# [179] → Aspek: Kualitas Kopi; Menu Lain | Keywords: JUARA, biasa rasanya; milonya, kopi susu
# — Saved checkpoint at tweet #179
# [180] → Aspek: Kualitas Kopi | Keywords: rasanya, 11/12 sama, creamy
# [181] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, lebih enak; tempat nongkrong
# [182] → Aspek: Suasana/Tempat | Keywords: Tomoro, fore, suka bgtttt
# [183] → Aspek: Promo | Keywords: voucher birthday, claim, keburu, buru" ambil
# [184] → Aspek: Harga/Nilai; Promo | Keywords: point; point
# [185] → Aspek: Menu Lain | Keywords: matcha frappe, coconut choco, coffee frappe, strawberry jasmine tea, butterscotch seasalt, kitkat, es teh hijau
# [186] → Aspek: Kualitas Kopi | Keywords: paling enak
# [187] → Aspek: Suasana/Tempat | Keywords: klaten, fore
# [188] → Aspek: Menu Lain | Keywords: Es teh
# [189] → Aspek: Harga/Nilai; Promo | Keywords: tuku, %; %
# — Saved checkpoint at tweet #189
# [190] → Aspek:  | Keywords:
# [191] → Aspek:  | Keywords:
# [192] → Aspek: Menu Lain | Keywords: enak, terlalu manis, ngga ada rasa pahitnya, matchanya, less sugar, da best
# [193] → Aspek: Kualitas Kopi | Keywords: kopi rum
# [194] → Aspek: Menu Lain | Keywords: menu, enak bgt
# [195] → Aspek:  | Keywords:
# [196] → Aspek: Suasana/Tempat | Keywords: nugas, mending, fore
# [197] → Aspek: Kualitas Kopi; Menu Lain | Keywords: nyoba, tidak menyesal, butterscotch latte, fore; butterscotch latte, ini
# [198] → Aspek:  | Keywords:
# [199] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kapal api classic, ultramilk karamel, suka manis, ga suka manis, pas, ultramilk mocca, coffe latte; ultramilk karamel, ultramilk mocca, coffe latte
# — Saved checkpoint at tweet #199
# [200] → Aspek: Kualitas Kopi | Keywords: konsisten, fav, zonk, enak, hint aneh, ga konsisten strong/ngga kopiny
# [201] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopsu senja; butterscotch sea salt
# [202] → Aspek: Promo | Keywords: duta Fore
# [203] → Aspek:  | Keywords:
# [204] → Aspek: Harga/Nilai; Menu Lain; Promo | Keywords: 15ribuan, diskon 50%; butterscotch sea salt latte; Download app, referral, diskon 50%
# [205] → Aspek: Kualitas Kopi | Keywords: kopi, andalan
# [206] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: enak bgt; bokek
# [207] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak, americano, prefer; matcha, enak, kemanisan
# [208] → Aspek: Menu Lain | Keywords: matchabae, enak
# [209] → Aspek: Suasana/Tempat | Keywords: skripsian, pilih ke fore
# — Saved checkpoint at tweet #209
# [210] → Aspek:  | Keywords:
# [211] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: g kopi bgt, masih ada rasa kopinya, g bisa minum kopi, sesak nafas, lemas; mahal, g habis, sayang bgt; saranin menu, g kopi bgt, masih ada rasa kopinya
# [212] → Aspek:  | Keywords:
# [213] → Aspek: Menu Lain | Keywords: almond choco, nagihin
# [214] → Aspek: Menu Lain | Keywords: seasalt latte
# [215] → Aspek:  | Keywords:
# [216] → Aspek: Kualitas Kopi | Keywords: persenan, enak
# [217] → Aspek: Kualitas Kopi | Keywords: BUTTERCREAM LATTE, BEST COFFEE, EVAH
# [218] → Aspek:  | Keywords:
# [219] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi seenak ini, seenak ini, lewatttttt; outlet lagi di PIK
# — Saved checkpoint at tweet #219
# [220] → Aspek: Kualitas Kopi; Menu Lain | Keywords: rasanya, kurang creamy, kebanyakan air, less ice, langsung minum; Saran menu, yang ena
# [221] → Aspek:  | Keywords:
# [222] → Aspek:  | Keywords:
# [223] → Aspek: Suasana/Tempat | Keywords: fore, kemenangan, (semarang only)
# [224] → Aspek: Menu Lain | Keywords: cocomint, fore, perlu dicoba
# [225] → Aspek: Kualitas Kopi; Menu Lain | Keywords: frappe, enak; frappe, oat latte series, hojicha, pandan latte, kitkat es teh, chizuuuuuu
# [226] → Aspek: Harga/Nilai; Promo | Keywords: voucher, eman; voucher, by apk
# [227] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: arabica, creme brulee latte, enak bgttt; 20-30an, 50k-an; arabica, creme brulee latte
# [228] → Aspek:  | Keywords:
# [229] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: rasa, konsistensi rasa, lumayan enak, ga suka, terlalu light, dominan susu aja; harga, lebih mahal, mahal
# — Saved checkpoint at tweet #229
# [230] → Aspek:  | Keywords:
# [231] → Aspek: Menu Lain | Keywords: fore, Minum, himalayan butterscotch
# [232] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: kopi, huek aslam naik; satu kurang, pesen dua/large
# [233] → Aspek:  | Keywords:
# [234] → Aspek:  | Keywords:
# [235] → Aspek: Layanan Pelanggan; Menu Lain | Keywords: pesan pake app, mas2nya, teriak manggil, blg lgi; Aren Latte, large, less sugar
# [236] → Aspek: Kualitas Kopi; Harga/Nilai; Suasana/Tempat | Keywords: enak, kopi bubuk; lebih hemat; Cafe lokal
# [237] → Aspek: Kualitas Kopi | Keywords: base kopi
# [238] → Aspek: Kualitas Kopi | Keywords: normal, kuat, minum kopi, demam
# [239] → Aspek: Menu Lain | Keywords: butterscotch
# — Saved checkpoint at tweet #239
# [240] → Aspek: Kualitas Kopi; Menu Lain | Keywords: Latte, Cold 'n Brew; Butterscotch Sea Salt Latte, Cold 'n Brew Selena
# [241] → Aspek: Kualitas Kopi | Keywords: mantulll
# [242] → Aspek: Kualitas Kopi | Keywords: enaaaakkk
# [243] → Aspek: Kualitas Kopi | Keywords: lidahku, cocok
# [244] → Aspek: Kualitas Kopi | Keywords: fore, ga bisa tidur malemnya
# [245] → Aspek: Harga/Nilai; Promo | Keywords: 12k, pot; specialforeyou, sering dapet
# [246] → Aspek: Kualitas Kopi | Keywords: Kopi, dabezzzz
# [247] → Aspek: Kualitas Kopi; Menu Lain | Keywords: less sugar, 8/10, gak suka terlalu manis; opsi pengganti, double ice shaken
# [248] → Aspek: Kualitas Kopi | Keywords: enak, bgtt
# [249] → Aspek: Kualitas Kopi | Keywords: enak
# — Saved checkpoint at tweet #249
# [250] → Aspek: Harga/Nilai; Promo | Keywords: disc 50%; Pake app, pake kode, disc 50%
# [251] → Aspek: Kualitas Kopi; Menu Lain | Keywords: creamer, campuran susunya, gak enak dilambung, americano, terbaik; coklatnya, terbaik
# [252] → Aspek: Kualitas Kopi; Menu Lain | Keywords: sukaaa, enakkk bgttttt, gilsss enakk bgtt; menu, ini
# [253] → Aspek: Harga/Nilai; Promo | Keywords: murah, bestt, oke; beli di app, murah
# [254] → Aspek:  | Keywords:
# [255] → Aspek: Kualitas Kopi | Keywords: nescafe, no sugar, manis bgt, bikin eneg
# [256] → Aspek:  | Keywords:
# [257] → Aspek:  | Keywords:
# [258] → Aspek:  | Keywords:
# [259] → Aspek: Kualitas Kopi; Menu Lain | Keywords: dolce coffe, strawberry espresso, per-latte- an, terlalu manis, manis banget; rose tea, semua menunya, Es.Teh Indonesia
# — Saved checkpoint at tweet #259
# [260] → Aspek: Kualitas Kopi | Keywords: suka
# [261] → Aspek: Kualitas Kopi; Menu Lain | Keywords: Masuk lidahku; kahluaaaa
# [262] → Aspek: Menu Lain | Keywords: Feel Matcha, Matcha
# [263] → Aspek:  | Keywords:
# [264] → Aspek: Kualitas Kopi | Keywords: ga enak, mirip susu kedelai
# [265] → Aspek: Menu Lain | Keywords: Keju, Batagor, Teh, Cilok, Blackforest, mie instant, Sate kambing, Ice cream, Melon, Seblak, Salad buah, Bayam
# [266] → Aspek:  | Keywords:
# [267] → Aspek: Suasana/Tempat | Keywords: dekat rumah
# [268] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopi baper, americano, manuka americano; es teh indonesia, gula nya tinggi bgt
# [269] → Aspek: Kualitas Kopi | Keywords: Butterscoth Sea Salt Late, Less sugar, Kopi Baper, secret recipes
# — Saved checkpoint at tweet #269
# [270] → Aspek: Kualitas Kopi; Harga/Nilai; Suasana/Tempat; Menu Lain | Keywords: praline, butterscotch sea salt, kyoto; harga tidak baik; tetangga; chicken buldak, corndog
# [271] → Aspek:  | Keywords:
# [272] → Aspek: Kualitas Kopi | Keywords: enak bgt
# [273] → Aspek: Kualitas Kopi | Keywords: kurang, enak
# [274] → Aspek: Suasana/Tempat | Keywords: jauh dari rumah, deket
# [275] → Aspek: Kualitas Kopi | Keywords: enak
# [276] → Aspek:  | Keywords:
# [277] → Aspek: Kualitas Kopi | Keywords: enak
# [278] → Aspek: Kualitas Kopi | Keywords: berry americano, pengen
# [279] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #279
# [280] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enakan, enak, ga seenak itu, kurengggg, Kurang strong, no sugar, dominan susunya; Matcha
# [281] → Aspek:  | Keywords:
# [282] → Aspek: Menu Lain | Keywords: Butterscotch sea salt
# [283] → Aspek: Kualitas Kopi | Keywords: mabok kopi, kopi mereka sangat ok, lambung gw
# [284] → Aspek: Menu Lain | Keywords: Kopi susu keluarga, caramel praline macchiato
# [285] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: ice americano; point
# [286] → Aspek: Menu Lain | Keywords: menu non coffee, non coffee
# [287] → Aspek: Kualitas Kopi; Menu Lain | Keywords: lebih enak, pait2 matcha nya, no sugar, less ice, less sugar, maniss, enak, creamy susunya, matcha nya ga berasa, minum susu; oatside matcha latte
# [288] → Aspek: Promo | Keywords: point
# [289] → Aspek: Harga/Nilai; Suasana/Tempat; Promo | Keywords: abis gajian, point, pas hemat; pas deket; point, pas hemat
# — Saved checkpoint at tweet #289
# [290] → Aspek: Kualitas Kopi | Keywords: terlalu light, kemanisan
# [291] → Aspek: Kualitas Kopi; Layanan Pelanggan; Menu Lain | Keywords: espresso, avocadofee, no sugar, signature chocolate; ndak beli lg, kasus adminnya nge somasi org di medsos, pencemaran nama baik, ngasih edukasi; signature chocolate
# [292] → Aspek:  | Keywords:
# [293] → Aspek: Tidak ada aspek spesifik yang dibahas secara eksplisit. Ulasan ini memberikan pujian umum kepada merek "fore" sebagai yang "terbaik" tanpa merinci aspek tertentu dari kedai kopi tersebut. | Keywords:
# [294] → Aspek: Suasana/Tempat | Keywords: buka di jember
# [295] → Aspek: Kualitas Kopi | Keywords: kenceng, kopi
# [296] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: seenak itu; rugi banget, ga beli kopi; non coffee
# [297] → Aspek: Kualitas Kopi | Keywords: nyicip, butterscotch, enakan
# [298] → Aspek:  | Keywords:
# [299] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #299
# [300] → Aspek:  | Keywords:
# [301] → Aspek: Harga/Nilai | Keywords: tidak kantong gweh friendly, kantong friendly, kantong
# [302] → Aspek:  | Keywords:
# [303] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi2 enak; di sekitaran gua, deket kantor, tinggal nyebrang rumah, tinggal nyebrang
# [304] → Aspek: Kualitas Kopi | Keywords: jantung hatiku
# [305] → Aspek: Suasana/Tempat | Keywords: Deket pintu tol, fore, dll
# [306] → Aspek: Kualitas Kopi | Keywords: Ice Spanish Latte, Berry Manuka Americano, Es Kopi Susu Tetangga, Kopi Susu Kampung, Es Kopi Roem
# [307] → Aspek: Kualitas Kopi | Keywords: rasanya ga masuk, fore/point, janjiw
# [308] → Aspek: Menu Lain | Keywords: matcha, enakk, susu nya diganti almond
# [309] → Aspek: Menu Lain | Keywords: Matcha Fore, kurang enak
# — Saved checkpoint at tweet #309
# [310] → Aspek: Suasana/Tempat | Keywords: mampir, fore
# [311] → Aspek:  | Keywords:
# [312] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enak, engga; store
# [313] → Aspek: Kualitas Kopi | Keywords: enak bgt
# [314] → Aspek: Kualitas Kopi; Promo | Keywords: seenak itu; diskon 50%, kode referral
# [315] → Aspek:  | Keywords:
# [316] → Aspek: Suasana/Tempat | Keywords: jauh
# [317] → Aspek: Kualitas Kopi | Keywords: varian, mirip fore
# [318] → Aspek: Menu Lain | Keywords: menu paling atas, menu
# [319] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #319
# [320] → Aspek: Kualitas Kopi | Keywords: creamy, manis, kopinya kerasa bgt, juwara beansnya, kombinasi keduanya
# [321] → Aspek: Promo | Keywords: requestnya, jgn 5 terus, gantian antara 3-5
# [322] → Aspek: Kualitas Kopi | Keywords: lebih suka kopi, sesuai selera, enak
# [323] → Aspek:  | Keywords:
# [324] → Aspek: Harga/Nilai; Promo | Keywords: paling murah, 20k++, ukurannya kecil, lumayan mahal, 15k, 18k; promo
# [325] → Aspek:  | Keywords:
# [326] → Aspek:  | Keywords:
# [327] → Aspek: Kualitas Kopi | Keywords: bikin puyeng
# [328] → Aspek: Menu Lain | Keywords: rekomen, menu, andalan
# [329] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #329
# [330] → Aspek: Kualitas Kopi | Keywords: ngerasain, Beli fore aja
# [331] → Aspek: Menu Lain | Keywords: menu apa
# [332] → Aspek: Menu Lain | Keywords: seasalt cream
# [333] → Aspek: Kualitas Kopi | Keywords: Fore, point coffe
# [334] → Aspek: Promo | Keywords: dapet apaa
# [335] → Aspek: Kualitas Kopi | Keywords: enak
# [336] → Aspek:  | Keywords:
# [337] → Aspek:  | Keywords:
# [338] → Aspek:  | Keywords:
# [339] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #339
# [340] → Aspek: Harga/Nilai; Suasana/Tempat | Keywords: mahal; kecil
# [341] → Aspek: Kualitas Kopi | Keywords: enak
# [342] → Aspek:  | Keywords:
# [343] → Aspek: Menu Lain | Keywords: non coffee, kafein
# [344] → Aspek:  | Keywords:
# [345] → Aspek:  | Keywords:
# [346] → Aspek: Menu Lain | Keywords: matcha, enak, muatchamu, ijonya
# [347] → Aspek: Harga/Nilai | Keywords: tuku
# [348] → Aspek: Kualitas Kopi | Keywords: B aja
# [349] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #349
# [350] → Aspek: Layanan Pelanggan; Promo | Keywords: ga dapet stiker; stiker
# [351] → Aspek: Kualitas Kopi | Keywords: enak, kenceng, begadang, deg2an
# [352] → Aspek:  | Keywords:
# [353] → Aspek: Kualitas Kopi | Keywords: fore, point, kopi tuku, banyak yg suka, pgn nyoba
# [354] → Aspek: Menu Lain | Keywords: Matcha fore, terenak
# [355] → Aspek:  | Keywords:
# [356] → Aspek:  | Keywords:
# [357] → Aspek: Menu Lain | Keywords: matcha, jatuh cinta
# [358] → Aspek: Harga/Nilai; Promo | Keywords: voucher, 3 bulan, download apk; voucher, download apk, 3 bulan
# [359] → Aspek: Kualitas Kopi; Menu Lain | Keywords: original enak, espressonya, coconutnya ena, manuka honey coffee enak; butterscotch sea salt latte
# — Saved checkpoint at tweet #359
# [360] → Aspek: Promo | Keywords: voucher, 50%, 3 kali, referral
# [361] → Aspek: Menu Lain | Keywords: Famicafe, point, tuku, fore, tomorro, nyobain
# [362] → Aspek: Layanan Pelanggan; Promo | Keywords: beli, ga dapet stiker; stiker, ga dapet
# [363] → Aspek: Suasana/Tempat | Keywords: Kangen, fore
# [364] → Aspek:  | Keywords:
# [365] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kerasa bgt, americanonya; manuka amer, triple peach amer
# [366] → Aspek: Kualitas Kopi; Menu Lain | Keywords: cocok, caramel praline, frappe; cocok, caramel praline, frappe
# [367] → Aspek:  | Keywords:
# [368] → Aspek: Kualitas Kopi | Keywords: kopinya, suka
# [369] → Aspek: Kualitas Kopi | Keywords: terlalu manis, the best
# — Saved checkpoint at tweet #369
# [370] → Aspek: Menu Lain | Keywords: Almond Milk, Passion Fruit with Lemonade Tea
# [371] → Aspek: Menu Lain; Promo | Keywords: Fore junior Milk Butterschot, versi gapake kopi; free sticker
# [372] → Aspek:  | Keywords:
# [373] → Aspek: Harga/Nilai | Keywords: jgn sering2 beli
# [374] → Aspek: Kualitas Kopi | Keywords: enak
# [375] → Aspek:  | Keywords:
# [376] → Aspek: Kualitas Kopi | Keywords: sedap, betul
# [377] → Aspek: Suasana/Tempat; Harga/Nilai; Promo; Menu Lain | Keywords: lebih kecil; lebih mahal; jarang promo; Matcha, kusuka
# [378] → Aspek: Menu Lain | Keywords: less sugar, semua
# [379] → Aspek: Menu Lain | Keywords: muffin fore, juara bgt, keras
# — Saved checkpoint at tweet #379
# [380] → Aspek: Kualitas Kopi | Keywords: enak sih, R&D nya gak maen2
# [381] → Aspek:  | Keywords:
# [382] → Aspek:  | Keywords:
# [383] → Aspek: Menu Lain | Keywords: matcha, coba
# [384] → Aspek: Suasana/Tempat | Keywords: posisinya, mending fore
# [385] → Aspek:  | Keywords:
# [386] → Aspek: Kualitas Kopi | Keywords: takarannya pas, ga perlu pesen less sugar, muanis bgt, strong
# [387] → Aspek: Kualitas Kopi | Keywords: nomor satu, emang
# [388] → Aspek:  | Keywords:
# [389] → Aspek: Kualitas Kopi | Keywords: enak, enakkkk bangettttt
# — Saved checkpoint at tweet #389
# [390] → Aspek: Kualitas Kopi | Keywords: juara, thicknessnya
# [391] → Aspek: Kualitas Kopi | Keywords: blm ku minum, malem bru kuminum, masih enakkk
# [392] → Aspek: Kualitas Kopi; Menu Lain | Keywords: terbest bangetttt, 1000/10; butterscoth seasalt, oat latte, matcha espresso
# [393] → Aspek: Layanan Pelanggan | Keywords: bayar, cash
# [394] → Aspek: Kualitas Kopi | Keywords: terdepan
# [395] → Aspek: Suasana/Tempat | Keywords: skripsian
# [396] → Aspek: Menu Lain | Keywords: minuman fore junior, ukurannya lebih kecil, reguler, non coffee, less sugar
# [397] → Aspek: Menu Lain | Keywords: fore matcha, enak bgt, susunya diganti, naik level
# [398] → Aspek: Kualitas Kopi; Menu Lain | Keywords: Kopi Baileys, juara; Kopi Baileys, juara
# [399] → Aspek: Suasana/Tempat | Keywords: buka di aceh
# — Saved checkpoint at tweet #399
# [400] → Aspek:  | Keywords:
# [401] → Aspek: Promo | Keywords: promo
# [402] → Aspek: Kualitas Kopi | Keywords: enakkk, barian
# [403] → Aspek: Kualitas Kopi | Keywords: top tier, kopinya
# [404] → Aspek: Layanan Pelanggan | Keywords: minta, less sugar
# [405] → Aspek: Kualitas Kopi | Keywords: so far so good, local coffee, agak kureng
# [406] → Aspek: Kualitas Kopi; Menu Lain | Keywords: my fav, MANIS BGT; kopi saku, buttercream latte, caramel praline macchiato, kitkat apa itu namanya es teh ind, chizu matcha, chizu redvel, lemonade berry
# [407] → Aspek: Menu Lain | Keywords: Avocadofee frape, kopi Pandan, Buttercream tiramisu latte, butterscotch sea salt, Thai tea, Silky cream rich choco, choco hazelnut
# [408] → Aspek: Kualitas Kopi | Keywords: Tuku, fore, point, ngga ada obat
# [409] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #409
# [410] → Aspek: Promo | Keywords: beli, fore junior, dapet stiker, persediaan masih ada
# [411] → Aspek: Kualitas Kopi; Menu Lain | Keywords: butterscotch sea salt latte; mysterious green frappe, thai tea, esteh susu nusantara, pudding
# [412] → Aspek: Menu Lain | Keywords: oat latte, double iced shaken latte, es teh susu nusantara
# [413] → Aspek:  | Keywords:
# [414] → Aspek:  | Keywords:
# [415] → Aspek: Suasana/Tempat | Keywords: fore
# [416] → Aspek: Kualitas Kopi | Keywords: top tier, kopi kopian
# [417] → Aspek: Kualitas Kopi | Keywords: da best
# [418] → Aspek: Harga/Nilai | Keywords: tuku
# [419] → Aspek: Kualitas Kopi | Keywords: taste, rasa kopi, bedain rasa
# — Saved checkpoint at tweet #419
# [420] → Aspek:  | Keywords:
# [421] → Aspek:  | Keywords:
# [422] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: taste, buttercream less sugar, caramel macchiato less sugar, double shaken; price, harga
# [423] → Aspek: Menu Lain | Keywords: KST Tuku, Calf Liquid Jefferson, KSK Famima, Butterscotch Fore
# [424] → Aspek:  | Keywords:
# [425] → Aspek: Promo | Keywords: stiker
# [426] → Aspek: Kualitas Kopi | Keywords: kopinya, gak merem, sampe pagi
# [427] → Aspek: Promo; Harga/Nilai | Keywords: fore sampe sebulan, vouchernya muncul sendiri, bisa pilih 1 menu, tanpa beli apapun; tanpa beli apapun, 1 menu
# [428] → Aspek: Kualitas Kopi | Keywords: kopi rasa
# [429] → Aspek: Suasana/Tempat | Keywords: kopisop, cuma ada di sby, storenya ada di seluruh indo
# — Saved checkpoint at tweet #429
# [430] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: terenak, suka, kopi; tempatnya cozy, enak, gawe, nongkrong; salted caramel, iced
# [431] → Aspek:  | Keywords:
# [432] → Aspek:  | Keywords:
# [433] → Aspek: Kualitas Kopi | Keywords: enak
# [434] → Aspek: Kualitas Kopi | Keywords: Kopsus Tetangga, Mocha, Kopsus Gula Aren, Kopi Baper, botolan
# [435] → Aspek:  | Keywords:
# [436] → Aspek: Promo | Keywords: aplikasi
# [437] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: seasalt latte, Enak; mahal banget
# [438] → Aspek: Menu Lain | Keywords: cokelat fore, seenak ituuuu, less sugar, terbaik
# [439] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #439
# [440] → Aspek: Suasana/Tempat | Keywords: tuku, bandung
# [441] → Aspek: Suasana/Tempat | Keywords: banyak kota, sby
# [442] → Aspek:  | Keywords:
# [443] → Aspek:  | Keywords:
# [444] → Aspek: Menu Lain | Keywords: DUA-DUANYAAAAA, best menu
# [445] → Aspek:  | Keywords:
# [446] → Aspek:  | Keywords:
# [447] → Aspek: Kualitas Kopi | Keywords: mual, minum kopi, sesruput doang, kafeinnya ga berasa, Fore, secinta itu
# [448] → Aspek:  | Keywords:
# [449] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #449
# [450] → Aspek:  | Keywords:
# [451] → Aspek:  | Keywords:
# [452] → Aspek:  | Keywords:
# [453] → Aspek: Kualitas Kopi; Menu Lain | Keywords: dolce, fav, ga ada obat; beng beng, fav, ga ada obat
# [454] → Aspek:  | Keywords:
# [455] → Aspek:  | Keywords:
# ✅ Done. All predictions saved.
