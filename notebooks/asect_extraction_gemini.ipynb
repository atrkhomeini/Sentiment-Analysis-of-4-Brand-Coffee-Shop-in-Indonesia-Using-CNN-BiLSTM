# %% [markdown]
# ASPECT EXTRACTION

# %%
import yaml

# Load API key from the YAML file
with open('../key/key.yml', 'r') as file:
    keys = yaml.safe_load(file)
    GEMINI_API_KEY = keys.get('GEMINI_API_KEY')

print("API key loaded successfully.")
# Out:
# API key loaded successfully.

# %%
import pandas as pd
import google.generativeai as genai
import time
import json
import os

# %%
# Ensure the client and model are correctly initialized
client = genai.configure(api_key=GEMINI_API_KEY)

# Inisialisasi model Gemini
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
df = pd.read_csv('../data/output/labelled.csv')
# Siapkan kolom hasil
if 'Predicted_Aspects' not in df.columns:
    df['Predicted_Aspects'] = ""
if 'Predicted_Keywords' not in df.columns:
    df['Predicted_Keywords'] = ""

# %%
# 2. Checkpoint
checkpoint_file = '../data/output/progress_checkpoint.json'
progress = {}
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, 'r') as f:
        progress = json.load(f)

# Looping untuk Zero-Shot Classification
save_interval = 10  # Simpan setiap 10 tweet
counter = 0

# %%
for idx, row in df.iterrows():
    tweet = row['Text']
    # Jika sudah pernah diproses skip
    if str(idx) in progress:
        df.at[idx, 'Predicted_Aspects'] = progress[str(idx)]['aspects']
        df.at[idx, 'Predicted_Keywords'] = progress[str(idx)]['keywords']
        continue
    
    prompt = f"""
    Identifikasi aspek-aspek berikut yang dibahas dalam ulasan Twitter tentang kedai kopi ini: Kualitas Kopi, Layanan Pelanggan, Harga/Nilai, Suasana/Tempat, Menu Lain, Promo. Untuk setiap aspek yang relevan, sebutkan kata-kata kunci terkait. Jika suatu aspek tidak disebutkan, abaikan.
    
    Ulasan: "{tweet}"

    Format:
    Aspek: [Aspek yang teridentifikasi]
    Kata Kunci: [Kata kunci dari ulasan]"""
    
    try:
        resp = model.generate_content([prompt])
        text = resp.text.strip()

        # --- Parsing sederhana berdasarkan baris “Aspek:” dan “Kata Kunci:” ---
        aspects, keywords = [], []
        for line in text.splitlines():
            if line.lower().startswith("aspek:"):
                aspects.append(line.split(":",1)[1].strip())
            elif line.lower().startswith("kata kunci:"):
                keywords.append(line.split(":",1)[1].strip())

        aspects_str  = "; ".join(aspects)
        keywords_str = "; ".join(keywords)

        df.at[idx, 'Predicted_Aspects']  = aspects_str
        df.at[idx, 'Predicted_Keywords'] = keywords_str
        progress[str(idx)] = {'aspects': aspects_str, 'keywords': keywords_str}
        counter += 1
        print(f"[{idx}] → Aspek: {aspects_str} | Keywords: {keywords_str}")

        # Simpan berkala
        if counter % save_interval == 0:
            with open(checkpoint_file, 'w') as f:
                json.dump(progress, f)
            df.to_excel('tweet_with_predicted_aspect_test.xlsx', index=False)
            print(f"— Saved checkpoint at tweet #{idx}")

        time.sleep(2.0)

    except Exception as e:
        print(f"Error on idx {idx}: {e}")
        df.at[idx, 'Predicted_Aspects']  = 'ERROR'
        df.at[idx, 'Predicted_Keywords'] = ''
        continue

# 4. Final save
with open(checkpoint_file, 'w') as f:
    json.dump(progress, f)
df.to_excel('tweet_with_predicted_aspect_test.xlsx', index=False)
print("✅ Done. All predictions saved.")
# Out:
# [60] → Aspek:  | Keywords:
# [61] → Aspek: Suasana/Tempat | Keywords: bikin, tegal, pekalongan, semarang, fore
# [62] → Aspek:  | Keywords:
# [63] → Aspek: Kualitas Kopi | Keywords: matcha, enaaaak
# [64] → Aspek: Kualitas Kopi; Promo | Keywords: manisnya diawal minum, mengeluh; diskonan
# [65] → Aspek: Kualitas Kopi | Keywords: fore esbatu, beda, cair
# [66] → Aspek: Kualitas Kopi | Keywords: fore, minum, enakkk
# [67] → Aspek: Kualitas Kopi | Keywords: berasa
# [68] → Aspek: Layanan Pelanggan | Keywords: fore, anjing males
# [69] → Aspek: Kualitas Kopi | Keywords: enak, magic, pelet, rd nya gak maen2
# — Saved checkpoint at tweet #69
# [70] → Aspek:  | Keywords:
# [71] → Aspek: Kualitas Kopi | Keywords: seneng kalii, minum, fore
# [72] → Aspek:  | Keywords:
# [73] → Aspek: Kualitas Kopi | Keywords: enak, bgtt, fore
# [74] → Aspek: Kualitas Kopi | Keywords: fore gula
# [75] → Aspek: Kualitas Kopi | Keywords: kopi2 fore, butterscotchbuttercream
# [76] → Aspek: Kualitas Kopi; Menu Lain | Keywords: frappe, enak, kopi, enakan fore; frappe
# [77] → Aspek: Kualitas Kopi | Keywords: enak banget
# [78] → Aspek: Kualitas Kopi | Keywords: fore, enakk, pointcoffee, enak
# [79] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: kopi terenak, suka kopi, djournal coffee; fore mall tempatnya, cozy, enak gawenongkrong; salted caramelnya, menu kesukaan iced
# — Saved checkpoint at tweet #79
# [80] → Aspek: Kualitas Kopi | Keywords: tuku, must try
# [81] → Aspek:  | Keywords:
# [82] → Aspek: Suasana/Tempat | Keywords: banyakk, fore, kopi kenangan, point coffee, tomoro, tuku
# [83] → Aspek:  | Keywords:
# [84] → Aspek:  | Keywords:
# [85] → Aspek: Kualitas Kopi; Promo | Keywords: enakkkk bangett; promonya
# [86] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi duarr nendang mata, kualitasnya suka beda gerai, kopi jadoelnya; suka terang, suka tengah2, gerai
# [87] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enak, kopi; kedai kopi lokal, daerahmu, bandung, missbee providore, fullmoon, garmelia, kopi teko, jatinangor
# [88] → Aspek: Kualitas Kopi | Keywords: point coffee, coffee
# [89] → Aspek: Menu Lain | Keywords: butterscotch, enaaak banget
# — Saved checkpoint at tweet #89
# [90] → Aspek:  | Keywords:
# [91] → Aspek: Suasana/Tempat | Keywords: fore, kopkem, point coffee
# [92] → Aspek: Kualitas Kopi | Keywords: enak banget
# [93] → Aspek: Kualitas Kopi | Keywords: lbh enak, kopi
# [94] → Aspek: Harga/Nilai; Promo | Keywords: tuku, poin; tuku, poin
# [95] → Aspek: Kualitas Kopi; Promo | Keywords: couve (asumsi "coffee"), makmur jaya (menunjukkan kepuasan secara keseluruhan yang bisa mencakup kualitas produk utama); poin (mengacu pada sistem poin loyalitas atau reward, yang merupakan bentuk promo)
# [96] → Aspek: Kualitas Kopi | Keywords: coffee, enak, mayan
# [97] → Aspek:  | Keywords:
# [98] → Aspek: Kualitas Kopi | Keywords: paten
# [99] → Aspek: Menu Lain | Keywords: jco
# — Saved checkpoint at tweet #99
# [100] → Aspek: Kualitas Kopi | Keywords: enak banget, katanya
# [101] → Aspek: Kualitas Kopi | Keywords: akhir2, suka, titik koma (mengindikasikan kualitas yang tidak konsisten/berubah-ubah)
# [102] → Aspek: Kualitas Kopi | Keywords: kopi, jagoan
# [103] → Aspek: Kualitas Kopi | Keywords: kopi, butterscotch cloud coffee, edisi
# [104] → Aspek: Menu Lain | Keywords: fore, tuku, hati
# [105] → Aspek:  | Keywords:
# [106] → Aspek: Kualitas Kopi | Keywords: lebihh enakk
# [107] → Aspek:  | Keywords:
# [108] → Aspek:  | Keywords:
# [109] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #109
# [110] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, enak, mestinya; nongkrong
# [111] → Aspek:  | Keywords:
# [112] → Aspek:  | Keywords:
# [113] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enak; indie, coffee shop
# [114] → Aspek: Kualitas Kopi; Harga/Nilai; Promo | Keywords: enak, kopi enak; harga, promo; promo
# [115] → Aspek:  | Keywords:
# [116] → Aspek: Layanan Pelanggan | Keywords: tim
# [117] → Aspek: Suasana/Tempat | Keywords: coffe coffe shop, fore, janjiw, kopi kenangan, point coffee
# [118] → Aspek: Kualitas Kopi | Keywords: fore, enak
# [119] → Aspek: Kualitas Kopi | Keywords: juara, rekomen, enak
# — Saved checkpoint at tweet #119
# [120] → Aspek:  | Keywords:
# [121] → Aspek: Kualitas Kopi | Keywords: fore, enak
# [122] → Aspek: Menu Lain | Keywords: non coffe, enakk, suka
# [123] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: enak; dibawah, harganya
# [124] → Aspek: Harga/Nilai; Promo | Keywords: promo; promo
# [125] → Aspek:  | Keywords:
# [126] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, enak; coffee shop, kecil2, nongkrong
# [127] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: ngopi enak2, kopi enak, enak; cafe2 lokal kecil lingkungan, menarik banget
# [128] → Aspek:  | Keywords:
# [129] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: kalah enak, starbucks; murahhh
# — Saved checkpoint at tweet #129
# [130] → Aspek:  | Keywords:
# [131] → Aspek:  | Keywords: fore, animo (jika diinterpretasikan sebagai 'suasana' atau 'vibe' tempat); shay (diinterpretasikan sebagai 'Chai')
# [132] → Aspek:  | Keywords:
# [133] → Aspek:  | Keywords:
# [134] → Aspek: Suasana/Tempat | Keywords: dom, fore, solo, jogja, couvee, magelang, kofibru
# [135] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak bangett, kopinya; matcha, tomoro, enakk, tipe matcha pahittt
# [136] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: coffee, enak, kopi bubuk; hemat
# [137] → Aspek: Menu Lain | Keywords: fore, jco
# [138] → Aspek: Promo | Keywords: tuku point
# [139] → Aspek: Kualitas Kopi | Keywords: da bestt
# — Saved checkpoint at tweet #139
# [140] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kona kopi, zerogram kopi; kalyan, gatau kota, gak kalu sby, sby
# [141] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: coklat, enak banget, terharu, enak disimpen, sisanya dikulkas, pas diminum enak; beli melulu, large; coklat, large
# [142] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enakkk banget; gabisa nongkrong
# [143] → Aspek: Suasana/Tempat | Keywords: deket rumahku, nongkrong, kerja, kafe
# [144] → Aspek:  | Keywords:
# [145] → Aspek: Harga/Nilai; Suasana/Tempat | Keywords: tuku, murah; point coffee
# [146] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, enak; lokal, rumah
# [147] → Aspek:  | Keywords:
# [148] → Aspek: Harga/Nilai | Keywords: pindah, starbucks, fore, tomoro
# [149] → Aspek: Kualitas Kopi | Keywords: best, so far
# — Saved checkpoint at tweet #149
# [150] → Aspek: Kualitas Kopi | Keywords: sedap
# [151] → Aspek: Kualitas Kopi | Keywords: coffee, enak
# [152] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enakkk; tempatnya, cozy banget
# [153] → Aspek:  | Keywords:
# [154] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak banget, gak kalah, sb, tomoro, mantap, kopinya; salt creamnya, matchanya, gak kalah, sb, tomoro
# [155] → Aspek: Suasana/Tempat | Keywords: enak, nongkrong, daerah du
# [156] → Aspek: Kualitas Kopi | Keywords: fore, tomoro, kopkenfamima, favorit, starbucks
# [157] → Aspek:  | Keywords:
# [158] → Aspek: Kualitas Kopi | Keywords: coffee, sihh
# [159] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enak, kopi, berasa classy; jkrt tnrg, maxx coffee, fore, djournal, vibes2, cocok kerja serius, gak norak
# — Saved checkpoint at tweet #159
# [160] → Aspek: Kualitas Kopi | Keywords: favorit, Fore
# [161] → Aspek:  | Keywords:
# [162] → Aspek: Kualitas Kopi | Keywords: nescafe zero gula, fore kopinya, americano, gak gak cocok, deg2an, kopi kenangan kopinya, gak cocok perut, sakit perut, melek
# [163] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: americano, strong, nescafe classic; coffee shop
# [164] → Aspek: Suasana/Tempat | Keywords: fore, fam mart, point coffee
# [165] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: enakk, sumpah; murah
# [166] → Aspek:  | Keywords:
# [167] → Aspek:  | Keywords:
# [168] → Aspek: Harga/Nilai; Promo | Keywords: wpoint, janji; wpoint, janji
# [169] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #169
# [170] → Aspek:  | Keywords:
# [171] → Aspek: Kualitas Kopi | Keywords: rasane, koyo, fore
# [172] → Aspek: Kualitas Kopi | Keywords: enak, tomoro point coffee
# [173] → Aspek: Suasana/Tempat; Menu Lain | Keywords: cafe lokal, daerah; jco, roti o
# [174] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: enak, tergolong mana2; tempatnya oke
# [175] → Aspek: Harga/Nilai | Keywords: harga murah, pengganti sbx
# [176] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: suka, kopi rempahnya, fore double shaken latte, mesen gula, pengen manis, engga manis2 banget; sebelahan, peoples cafe; enak, pesen makan
# [177] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: point coffee, enak; fore, comfy
# [178] → Aspek: Kualitas Kopi | Keywords: creamy, strong, kopinya, suka
# [179] → Aspek: Kualitas Kopi | Keywords: enakan
# — Saved checkpoint at tweet #179
# [180] → Aspek: Layanan Pelanggan | Keywords: salah pesen
# [181] → Aspek: Suasana/Tempat | Keywords: ihh sebel banget, deket fore
# [182] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopi irish, wishki, bahannya, halal; mie setan iblis, mie var gacoan, mie suit
# [183] → Aspek: Layanan Pelanggan | Keywords: dm fore nya langsungg
# [184] → Aspek: Kualitas Kopi | Keywords: fore buttercream latte, best coffee evah
# [185] → Aspek: Kualitas Kopi | Keywords: fore, butterscoath, kopi, braun
# [186] → Aspek: Menu Lain | Keywords: kopsus gula aren, kopi kenangan ceo secret fore butterscot sea salt, coffee palm gula latte, coklat frappe, gula
# [187] → Aspek: Kualitas Kopi | Keywords: butterscotch seasalt latte, enak bgtt
# [188] → Aspek: Harga/Nilai | Keywords: budget
# [189] → Aspek: Harga/Nilai; Suasana/Tempat | Keywords: mahal; kecil
# — Saved checkpoint at tweet #189
# [190] → Aspek: Kualitas Kopi | Keywords: kemanisan
# [191] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords
→ Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: kopi fore; bungkus; nasi rames telor
# [394] → Aspek: Kualitas Kopi | Keywords: lupa, fore, gula, enak
# [395] → Aspek: Menu Lain | Keywords: makanan, cheesecake, enak
# [396] → Aspek: Kualitas Kopi | Keywords: matos, fore
# [397] → Aspek: Harga/Nilai | Keywords: kantong gweh friendly
# [398] → Aspek: Kualitas Kopi | Keywords: fore, enak
# [399] → Aspek: Kualitas Kopi; Menu Lain | Keywords: coffee, bandingin, beda; ditanya menu, point coffee, fore, bandingin, beda
# — Saved checkpoint at tweet #399
# [400] → Aspek: Layanan Pelanggan; Menu Lain | Keywords: ditanya, bahas, nyambung nya dimaneee; menu, indomaret point coffee
# [401] → Aspek: Menu Lain | Keywords: menu2, racuni, fore
# [402] → Aspek: Menu Lain | Keywords: menu2 fore, rekomendasi netijen
# [403] → Aspek:  | Keywords:
# [404] → Aspek: Kualitas Kopi | Keywords: pengen fore
# [405] → Aspek: Kualitas Kopi | Keywords: kemanisan, order gula
# [406] → Aspek: Kualitas Kopi | Keywords: menu minuman, enakk, rekomendasi
# [407] → Aspek: Kualitas Kopi | Keywords: hazelnut fore, enaaakkk
# [408] → Aspek: Kualitas Kopi | Keywords: kopi, gak suka kopi, nyoba, fore
# [409] → Aspek: Kualitas Kopi | Keywords: seenak
# — Saved checkpoint at tweet #409
# [410] → Aspek:  | Keywords:
# [411] → Aspek:  | Keywords:
# [412] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopinya pekat, varian gasuka kopi, gada kopinya; manis asin kres kres crumblenya, fore kids, gada kopinya, beda samasama enak
# [413] → Aspek: Harga/Nilai; Suasana/Tempat; Menu Lain | Keywords: harganya, pricey; bogor, fore; tiramisu, nyoba
# [414] → Aspek: Kualitas Kopi | Keywords: kopi, gabisa minum kopi, fore large
# [415] → Aspek: Kualitas Kopi | Keywords: terwenak
# [416] → Aspek: Kualitas Kopi | Keywords: butterscotch sea salt, enak bgttt
# [417] → Aspek: Menu Lain | Keywords: menu, fore
# [418] → Aspek: Kualitas Kopi | Keywords: seenak, seasalt latte
# [419] → Aspek: Kualitas Kopi | Keywords: strong, gerd
# — Saved checkpoint at tweet #419
# [420] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: enaak; harga, muraah; menu, enaak
# [421] → Aspek: Kualitas Kopi | Keywords: gak minum fore
# [422] → Aspek: Harga/Nilai | Keywords: uang, gagal
# [423] → Aspek: Suasana/Tempat | Keywords: gada tmn, fore
# [424] → Aspek:  | Keywords:
# [425] → Aspek: Kualitas Kopi | Keywords: terlight, dibanding franchise kopi2, varian manis, dominan manisnya, paitnya, asam, berasa kopinya, sugar1 shot, espresso
# [426] → Aspek:  | Keywords:
# [427] → Aspek: Kualitas Kopi | Keywords: kopinya fore, mules
# [428] → Aspek: Kualitas Kopi | Keywords: enakk bangett, top 1
# [429] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #429
# [430] → Aspek: Suasana/Tempat | Keywords: kangen fore, serang cilegon, gada investor franchise brand
# [431] → Aspek: Kualitas Kopi | Keywords: kopi, best banget, asli
# [432] → Aspek: Kualitas Kopi | Keywords: strong, sesek, mual, enak
# [433] → Aspek: Suasana/Tempat | Keywords: disini, fore, anjerrrrrnjjkk
# [434] → Aspek: Suasana/Tempat | Keywords: fore tutup, tutup, sedih
# [435] → Aspek: Kualitas Kopi | Keywords: asam lambung, minum fore, gak bikin kumat
# [436] → Aspek: Kualitas Kopi | Keywords: kuat kopi, tremor, debar, muntah
# [437] → Aspek: Kualitas Kopi | Keywords: kangen, fore
# [438] → Aspek:  | Keywords:
# [439] → Aspek: Kualitas Kopi | Keywords: kopi, titisan surga
# — Saved checkpoint at tweet #439
# [440] → Aspek: Suasana/Tempat | Keywords: fore, aman aman
# [441] → Aspek: Promo | Keywords: lupa beli, fore, eh bjir
# [442] → Aspek: Menu Lain | Keywords: non coffeenya, matcha latte, wajib banget cobain, enak banget banget bgtttttt
# [443] → Aspek: Harga/Nilai; Menu Lain | Keywords: 10rb, uk segelas kopi fore reguler; es buah, buahnya dikit
# [444] → Aspek: Harga/Nilai; Promo | Keywords: gratis; gratis
# [445] → Aspek:  | Keywords:
# [446] → Aspek: Suasana/Tempat | Keywords: enak banget vibesnya, duduk trotoar, nyaman banget
# [447] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain | Keywords: enakk, butterscotch; deket uang; butterscotch, varian
# [448] → Aspek:  | Keywords:
# [449] → Aspek: Harga/Nilai; Promo | Keywords: gratisan, ngeredeem, birthday gift; gratisan, ngeredeem, birthday gift, dr fore
# — Saved checkpoint at tweet #449
# [450] → Aspek: Kualitas Kopi | Keywords: macha, fore, sedunia
# [451] → Aspek: Kualitas Kopi | Keywords: kopi, enak
# [452] → Aspek:  | Keywords:
# [453] → Aspek: Kualitas Kopi | Keywords: suka, caramel praline macchiato, buttercream latte
# [454] → Aspek: Harga/Nilai; Promo | Keywords: voucher, claim, untung, pas banget; voucher birthday, claim, pas banget, untung
# [455] → Aspek: Harga/Nilai; Promo | Keywords: birthday reward; ulang klaim, birthday reward, app
# [456] → Aspek: Menu Lain | Keywords: paket hampers
# [457] → Aspek: Kualitas Kopi | Keywords: tetep enak, pandan latte
# [458] → Aspek: Suasana/Tempat | Keywords: ramai, mengantri, mager
# [459] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #459
# [460] → Aspek:  | Keywords:
# [461] → Aspek:  | Keywords:
# [462] → Aspek: Kualitas Kopi | Keywords: nyobain, kopi, fore point coffee, tetangga sebelah
# [463] → Aspek:  | Keywords:
# [464] → Aspek: Kualitas Kopi | Keywords: tahta tertinggi, kopi
# [465] → Aspek: Kualitas Kopi; Suasana/Tempat; Promo | Keywords: coffee; famima; fore point
# [466] → Aspek:  | Keywords:
# [467] → Aspek:  | Keywords:
# [468] → Aspek: Suasana/Tempat | Keywords: point coffee, fore
# [469] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #469
# [470] → Aspek: Kualitas Kopi | Keywords: butterscotch sea salt latter, janjiw kopsus sahabat, tuku kopsus tetangga, kopsus, extra susu
# [471] → Aspek: Kualitas Kopi | Keywords: suka, 1tuku, 2fore, 3 famima
# [472] → Aspek: Kualitas Kopi | Keywords: cinta padamu, tuku
# [473] → Aspek:  | Keywords:
# [474] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi; fore, soekulo, point coffee, tomoro
# [475] → Aspek:  | Keywords:
# [476] → Aspek:  | Keywords:
# [477] → Aspek: Kualitas Kopi | Keywords: gak strong kopinya, coffee addict suka, ocean blue latte, butterscotch sea salt
# [478] → Aspek: Kualitas Kopi | Keywords: fore butterscotch sea saltnya
# [479] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #479
# [480] → Aspek: Menu Lain | Keywords: matchanya
# [481] → Aspek: Harga/Nilai | Keywords: murah, tengah2, lil bit price, fore
# [482] → Aspek: Kualitas Kopi | Keywords: cinta banget
# [483] → Aspek: Kualitas Kopi | Keywords: arabika, tomoro, terbaek
# [484] → Aspek:  | Keywords:
# [485] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: konsistensi kopi, lumayan enak, terang dominan susu, arabica; segi harga, mahal
# [486] → Aspek: Kualitas Kopi; Menu Lain | Keywords: arabica, enak sih; coffee soft ice cream, enak sih
# [487] → Aspek: Kualitas Kopi | Keywords: best of 3, fore, tuku kopi, kopi kenangan
# [488] → Aspek: Kualitas Kopi | Keywords: nyoba, tukunakosama, tomoro, org, enak, fore, pling enak
# [489] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #489
# [490] → Aspek:  | Keywords:
# [491] → Aspek: Kualitas Kopi | Keywords: kopi, arabica, nyoba
# [492] → Aspek: Suasana/Tempat | Keywords: tutup, ditempatkuuu
# [493] → Aspek: Suasana/Tempat | Keywords: fore
# [494] → Aspek:  | Keywords:
# [495] → Aspek: Menu Lain | Keywords: gabisa milih, janjiw kenangan, tuku
# [496] → Aspek:  | Keywords:
# [497] → Aspek: Kualitas Kopi | Keywords: arabica
# [498] → Aspek:  | Keywords:
# [499] → Aspek: Kualitas Kopi | Keywords: mantap banget
# — Saved checkpoint at tweet #499
# [500] → Aspek: Kualitas Kopi | Keywords: manis2, creamy, kopi kenangan, fore, point coffee
# [501] → Aspek: Kualitas Kopi | Keywords: fore, point coffee, tuku, 1, 2, 3
# [502] → Aspek:  | Keywords:
# [503] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain; Promo | Keywords: best fore butterscotch, woww, enak banget, nothing spesial; mahal, lbh murahan; best fore butterscotch, nothing spesial jj; promo beda
# [504] → Aspek: Kualitas Kopi | Keywords: ngepasss banget deh
# [505] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: terbaik, enak; budgetnya murce
# [506] → Aspek:  | Keywords:
# [507] → Aspek: Suasana/Tempat | Keywords: point coffee, tuku, fore, kopi kenangan, jokopi, duabestttt
# [508] → Aspek:  | Keywords:
# [509] → Aspek: Kualitas Kopi | Keywords: kopi kenangan, favorit, fore, point coffee, tomoro, tuku kopi, belinya
# — Saved checkpoint at tweet #509
# [510] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: coffee, favorit; family mart
# [511] → Aspek: Kualitas Kopi | Keywords: urutan selera, janjiw, tomoro, fore, point coffee, kopi kenangan, nyoba
# [512] → Aspek: Kualitas Kopi | Keywords: arabica
# [513] → Aspek: Kualitas Kopi | Keywords: kemanisan
# [514] → Aspek: Kualitas Kopi | Keywords: strong, banget, bikin tidur, mantap, minum, perjalanan, ngantuk
# [515] → Aspek: Kualitas Kopi | Keywords: americano, juara
# [516] → Aspek: Harga/Nilai | Keywords: harga, tuku
# [517] → Aspek: Kualitas Kopi | Keywords: strong kopi
# [518] → Aspek:  | Keywords:
# [519] → Aspek: Kualitas Kopi | Keywords: enak, ktnya enak, fore
# — Saved checkpoint at tweet #519
# [520] → Aspek: Kualitas Kopi | Keywords: suka, fore (implikasinya menyukai produk kopi mereka), nyoba
# [521] → Aspek: Kualitas Kopi | Keywords: enak, engga
# [522] → Aspek:  | Keywords:
# [523] → Aspek:  | Keywords:
# [524] → Aspek: Kualitas Kopi | Keywords: kopi creamy manis, kopinya kerasa banget, juwara beansnya, kombinasi keduanya
# [525] → Aspek: Harga/Nilai; Suasana/Tempat | Keywords: tuku, kesampeannn; fore kopi, kenangan, point coffee, janjiw
# [526] → Aspek: Kualitas Kopi | Keywords: kopi, americano, triple peachberry manuka
# [527] → Aspek: Kualitas Kopi | Keywords: gasuka kopinya, paitt
# [528] → Aspek: Harga/Nilai | Keywords: tuku
# [529] → Aspek: Kualitas Kopi | Keywords: point coffee, coffee fore, terbaik
# — Saved checkpoint at tweet #529
# [530] → Aspek: Kualitas Kopi | Keywords: coffee, terbaik
# [531] → Aspek: Kualitas Kopi | Keywords: top tier, arabica, masuk seleraku
# [532] → Aspek: Kualitas Kopi | Keywords: kopi, enak, strong kopinya, add shot
# [533] → Aspek: Suasana/Tempat | Keywords: famima
# [534] → Aspek: Kualitas Kopi | Keywords: manis manis
# [535] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: fore; famima
# [536] → Aspek: Kualitas Kopi | Keywords: arabica, kopinya, suka
# [537] → Aspek:  | Keywords:
# [538] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: suka kopi; tuku, kopi sakunya
# [539] → Aspek: Kualitas Kopi | Keywords: arabica, best of best, okeee bangettt
# — Saved checkpoint at tweet #539
# [540] → Aspek: Kualitas Kopi | Keywords: da best
# [541] → Aspek:  | Keywords:
# [542] → Aspek: Kualitas Kopi | Keywords: kopinya, enak
# [543] → Aspek:  | Keywords:
# [544] → Aspek:  | Keywords:
# [545] → Aspek:  | Keywords:
# [546] → Aspek:  | Keywords:
# [547] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: aman lidah, aman lambung; aman dompet
# [548] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: kopi kenangan, beli fore (menyiratkan preferensi dan perbandingan kualitas); uang, beli
# [549] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, keren, terbaik; kenangan, terbaik
# — Saved checkpoint at tweet #549
# [550] → Aspek: Harga/Nilai; Promo | Keywords: promo; promo
# [551] → Aspek:  | Keywords:
# [552] → Aspek: Promo | Keywords: seperdua, fore
# [553] → Aspek:  | Keywords:
# [554] → Aspek: Kualitas Kopi | Keywords: kopi kenangan, fore, enak
# [555] → Aspek:  | Keywords:
# [556] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: coffe, point coffee, fore; tuku
# [557] → Aspek: Kualitas Kopi | Keywords: suka, fore, pandan
# [558] → Aspek: Suasana/Tempat | Keywords: point coffee, kedai kopi, fore
# [559] → Aspek: Menu Lain | Keywords: menu, sedapp
# — Saved checkpoint at tweet #559
# [560] → Aspek:  | Keywords:
# [561] → Aspek:  | Keywords:
# [562] → Aspek:  | Keywords:
# [563] → Aspek: Kualitas Kopi | Keywords: bestt
# [564] → Aspek:  | Keywords:
# [565] → Aspek: Kualitas Kopi | Keywords: fore butterscotch, enak banget
# [566] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi, fore kopi, kenangan; disini
# [567] → Aspek: Promo | Keywords: fore, senang hati, disuruh ngabisin 3 cup, mauuu
# [568] → Aspek:  | Keywords:
# [569] → Aspek: Harga/Nilai | Keywords: segi harga, tuku coba
# — Saved checkpoint at tweet #569
# [570] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: arabica, ntap banget; murah banget, murah, mahal dikit
# [571] → Aspek: Harga/Nilai; Promo | Keywords: tuku, coffee foree; tuku, coffee foree
# [572] → Aspek: Kualitas Kopi | Keywords: fore point coffee tomoro janjiw, udah engga masuk listku
# [573] → Aspek: Kualitas Kopi | Keywords: best
# [574] → Aspek:  | Keywords:
# [575] → Aspek: Kualitas Kopi; Layanan Pelanggan; Harga/Nilai | Keywords: enak, arabica kureng, coffeenya kaya minum air; pesennya salah; harganya mehong
# [576] → Aspek: Kualitas Kopi | Keywords: famima point coffee, enak
# [577] → Aspek:  | Keywords:
# [578] → Aspek: Kualitas Kopi | Keywords: best, fore
# [579] → Aspek: Menu Lain | Keywords: nonkopi, pesen nonkopi
# — Saved checkpoint at tweet #579
# [580] → Aspek:  | Keywords:
# [581] → Aspek: Suasana/Tempat | Keywords: fore
# [582] → Aspek: Menu Lain | Keywords: sisanya nyoba
# [583] → Aspek:  | Keywords:
# [584] → Aspek: Kualitas Kopi | Keywords: kopi, icip, enak
# [585] → Aspek: Suasana/Tempat | Keywords: fore, famima, tuku
# ...
# [2083] → Aspek:  | Keywords:
# [2084] → Aspek: Harga/Nilai; Promo | Keywords: potongan 50; referral, f76a27, potongan 50
# [2085] → Aspek: Kualitas Kopi | Keywords: lidahku cocok
# [2086] → Aspek: Harga/Nilai | Keywords: bedanya, fore junior
# [2087] → Aspek:  | Keywords:
# [2088] → Aspek: Kualitas Kopi | Keywords: gak bikin lambung berguncang, enakan tomoro fore kopi kenangan janjiw, minum kopi perutnya blubuk2
# [2089] → Aspek: Menu Lain | Keywords: himalayan butterscotch
# [2090] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: dingin, panas, kemasan, cakep; betah
# — Saved checkpoint at tweet #2090
# [2091] → Aspek: Kualitas Kopi; Menu Lain | Keywords: fore pandan, hihihiiw banget, diminum sehariann; fore pandan
# [2092] → Aspek: Kualitas Kopi | Keywords: butterscotch kopken, enakan, fore asli
# [2093] → Aspek: Kualitas Kopi | Keywords: buttercream latte
# [2094] → Aspek: Harga/Nilai; Promo | Keywords: diskon 50; pakai aplikasi, masukkan referral, diskon 50
# [2095] → Aspek:  | Keywords:
# [2096] → Aspek:  | Keywords:
# [2097] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopi, seenak; non coffee
# [2098] → Aspek: Menu Lain | Keywords: matcha, milo, junior
# [2099] → Aspek: Suasana/Tempat | Keywords: cupnya collectible
# [2100] → Aspek: Layanan Pelanggan | Keywords: fore cup, masi huh
# — Saved checkpoint at tweet #2100
# [2101] → Aspek: Kualitas Kopi | Keywords: kerasa matcha nya, pait paitnya, suka matcha type ituu
# [2102] → Aspek: Kualitas Kopi; Menu Lain | Keywords: kopi, bestnya; non coffee, matcha
# [2103] → Aspek: Kualitas Kopi | Keywords: kopi, dijamah
# [2104] → Aspek: Harga/Nilai; Promo | Keywords: diskon; diskon, app
# [2105] → Aspek: Suasana/Tempat | Keywords: jatinangor, kecamatan kecil, fore
# [2106] → Aspek: Menu Lain | Keywords: menu, makanannya
# [2107] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain; Promo | Keywords: terenak, butter cream tiramisu, butterscotch sea salt, almond choco, caramel praline, tropical manuka hibiscus; diskon 50, pakai aplikasi; top 5 menu fore, butter cream tiramisu, butterscotch sea salt, almond choco, caramel praline, tropical manuka hibiscus; diskon 50, pakai aplikasi
# [2108] → Aspek: Harga/Nilai; Promo | Keywords: diskon 50; aplikasi fore, diskon 50, 3 transaksi
# [2109] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: latte, butterscotch sea salt, fore (merujuk pada Fore Coffee sebagai penyedia kopi); fore (merujuk pada Fore Coffee sebagai nama tempat)
# [2110] → Aspek: Suasana/Tempat | Keywords: pas banget, jalan
# — Saved checkpoint at tweet #2110
# [2111] → Aspek: Harga/Nilai; Promo | Keywords: diskon, 50; pengguna fore, diskon, 50, maks 3x trx
# [2112] → Aspek: Kualitas Kopi; Menu Lain | Keywords: manuka amer, triple peach amer, kerasa banget, americanonya, fore; manuka amer, triple peach amer
# [2113] → Aspek:  | Keywords:
# [2114] → Aspek:  | Keywords:
# [2115] → Aspek:  | Keywords:
# [2116] → Aspek:  | Keywords:
# [2117] → Aspek: Menu Lain | Keywords: matcha, cintaku
# [2118] → Aspek: Suasana/Tempat | Keywords: rumah wujud berkah
# [2119] → Aspek:  | Keywords:
# [2120] → Aspek: Harga/Nilai; Menu Lain; Promo | Keywords: diskon; food; diskon
# — Saved checkpoint at tweet #2120
# [2121] → Aspek: Kualitas Kopi | Keywords: enak
# [2122] → Aspek: Kualitas Kopi | Keywords: enakan, fore, tuku
# [2123] → Aspek:  | Keywords:
# [2124] → Aspek: Kualitas Kopi | Keywords: best
# [2125] → Aspek: Kualitas Kopi | Keywords: asli, enak, point coffee, coffefore
# [2126] → Aspek: Kualitas Kopi | Keywords: gasuka, dominan pahit, tomoro
# [2127] → Aspek: Harga/Nilai; Suasana/Tempat; Promo | Keywords: diskon ojol; kotaku tomoro mana2, fore mall, kampuskerja, dalem mall banget, pusat kota; sllu diskon ojol
# [2128] → Aspek: Kualitas Kopi | Keywords: enakan, fore
# [2129] → Aspek:  | Keywords:
# [2130] → Aspek: Kualitas Kopi | Keywords: enak, enakan, fore
# — Saved checkpoint at tweet #2130
# [2131] → Aspek: Kualitas Kopi; Layanan Pelanggan; Harga/Nilai; Suasana/Tempat | Keywords: enak, selera, ngulik kopi daerah, kopi daerah, enak banget, better; barista, suka ngulik; kafe2 umkm, highbrand, better fore; kafe2 umkm
# [2132] → Aspek: Kualitas Kopi | Keywords: triple peach americano, enak banget
# [2133] → Aspek: Menu Lain | Keywords: matcha
# [2134] → Aspek: Kualitas Kopi; Menu Lain | Keywords: top, matcha; matcha
# [2135] → Aspek: Menu Lain | Keywords: greentea matcha, enaaak, bikin nemu pas lidah
# [2136] → Aspek: Kualitas Kopi | Keywords: matcha, enakkk
# [2137] → Aspek: Kualitas Kopi | Keywords: enak
# [2138] → Aspek: Menu Lain | Keywords: gula
# [2139] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: kopi kanto, lumayan strong, hint paitnya, luvs gula; outlet beda, deket kopi kanto; matcha tomoro
# [2140] → Aspek: Suasana/Tempat; Menu Lain | Keywords: ngecafe, fore; matcha
# — Saved checkpoint at tweet #2140
# [2141] → Aspek: Kualitas Kopi | Keywords: enak, mantap
# [2142] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enakkk, matchanya; matchanya
# [2143] → Aspek: Menu Lain | Keywords: matcha tomoro, debat foree, enak, matcha lawson, enak bgttt
# [2144] → Aspek: Kualitas Kopi; Menu Lain | Keywords: berasa, matcha laen, minuman gula, dikasih matcha, feel matcha enak; matcha, matcha fore, minuman
# [2145] → Aspek: Kualitas Kopi | Keywords: enak
# [2146] → Aspek: Kualitas Kopi | Keywords: matcha favoritku
# [2147] → Aspek: Kualitas Kopi; Menu Lain | Keywords: (Tidak disebutkan - ulasan berfokus pada minuman non-kopi); matcha terenak, greentea fore ice blended, gatau nama menunya lupa, enak bgttt, creamy, paitnya kerasa, enak banget
# [2148] → Aspek: Kualitas Kopi; Menu Lain | Keywords: nyeduh, kopi kenangan, enak, pesennya, sugarnosugar, ice creamy, hint pait2nya, fore, tomoro, enakk jugaaa; matchamu, homelab, feelmatcha, enak
# [2149] → Aspek: Kualitas Kopi; Menu Lain | Keywords: brand kopi, matchanya enak, seduh; matchanya
# [2150] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak, matchabae, kopi kenangan; matchabae
# — Saved checkpoint at tweet #2150
# [2151] → Aspek: Kualitas Kopi; Menu Lain | Keywords: matchanya, enak; matchanya
# [2152] → Aspek: Kualitas Kopi | Keywords: matcha, enakk, susu, almond
# [2153] → Aspek: Kualitas Kopi | Keywords: tomoro, rill, juara bangettt, fore
# [2154] → Aspek: Kualitas Kopi; Menu Lain | Keywords: matchanya fore; matchanya
# [2155] → Aspek: Kualitas Kopi | Keywords: matcha, enak matchanya
# [2156] → Aspek: Menu Lain | Keywords: matcha, minuman, minuman kesukaan
# [2157] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enak, matcha taru, super enak pwoll, leton, mayan sih; matcha taru, leton
# [2158] → Aspek: Kualitas Kopi; Suasana/Tempat; Menu Lain | Keywords: greentea chatramue, pakai mesin descale, tambahin susu oat, gula aren, mantap, enak parah, matcha nya; jatinangor; greentea chatramue, susu oat, gula aren, matcha nya
# [2159] → Aspek: Menu Lain | Keywords: matchamu
# [2160] → Aspek: Kualitas Kopi | Keywords: enak, matcha, manis doang
# — Saved checkpoint at tweet #2160
# [2161] → Aspek: Kualitas Kopi; Menu Lain | Keywords: suka hojichanya, matchamu, hojicha latte enak banget; hojichanya, matchamu, fore menu, hojicha latte
# [2162] → Aspek: Kualitas Kopi | Keywords: enak
# [2163] → Aspek: Kualitas Kopi | Keywords: fore ice blended, sumpah terenakkkk
# [2164] → Aspek: Kualitas Kopi | Keywords: enak, kopi, oatmilk, surga dunia
# [2165] → Aspek: Kualitas Kopi | Keywords: matcha, pahit, kemanisan, susu, kremer, puol pahitnya, kaya matcha sasetan, starbucks, point coffee, coffee fore
# [2166] → Aspek: Kualitas Kopi; Suasana/Tempat | Keywords: kopi kenangan, hot, half gula, cold creamy, enak, gula pakai toping seasalt, mantap, point coffee, coffee gula; best allure
# [2167] → Aspek: Menu Lain | Keywords: matcha
# [2168] → Aspek:  | Keywords:
# [2169] → Aspek: Kualitas Kopi | Keywords: matcha, mayan si, enak jugaaa
# [2170] → Aspek: Suasana/Tempat | Keywords: samping e fore
# — Saved checkpoint at tweet #2170
# [2171] → Aspek: Menu Lain | Keywords: menu, fore, cobain
# [2172] → Aspek: Kualitas Kopi | Keywords: fore, gada lawan
# [2173] → Aspek: Suasana/Tempat | Keywords: huhuhu, fore, dom kuu
# [2174] → Aspek: Suasana/Tempat | Keywords: cilegon, gada fore
# [2175] → Aspek: Suasana/Tempat | Keywords: buka jember, jember
# [2176] → Aspek: Kualitas Kopi | Keywords: butterscotch, cinta banget
# [2177] → Aspek: Promo | Keywords: birthday voucher
# [2178] → Aspek:  | Keywords:
# [2179] → Aspek: Harga/Nilai; Promo | Keywords: free kopi, discount 50; birthday treat, free kopi fore, download appnya, kode referral, registrasi, discount 50
# [2180] → Aspek: Promo; Harga/Nilai | Keywords: voucer, fore; voucer
# — Saved checkpoint at tweet #2180
# [2181] → Aspek: Suasana/Tempat | Keywords: packaging, simple, bagus
# [2182] → Aspek: Promo | Keywords: pengennn, cek, fore apk
# [2183] → Aspek:  | Keywords:
# [2184] → Aspek: Promo | Keywords: apk fore, gadaa
# [2185] → Aspek:  | Keywords:
# [2186] → Aspek: Suasana/Tempat | Keywords: fore, kotaku
# [2187] → Aspek: Kualitas Kopi | Keywords: fore, lambungku ngambek-ngambeknya
# [2188] → Aspek: Promo | Keywords: plan kakak, tanggal 25, beli 1 gratis 1
# [2189] → Aspek:  | Keywords:
# [2190] → Aspek: Menu Lain | Keywords: hot syakled, ajig, enaknya
# — Saved checkpoint at tweet #2190
# [2191] → Aspek: Kualitas Kopi | Keywords: kopi, afdoool
# [2192] → Aspek: Kualitas Kopi | Keywords: kopi, varian, tani
# [2193] → Aspek: Kualitas Kopi; Menu Lain | Keywords: rekomen, menu, andalan; rekomen, menu, andalan
# [2194] → Aspek: Promo | Keywords: voucher birthday, apk fore, min 3bln, tanggal ulang
# [2195] → Aspek: Kualitas Kopi | Keywords: fore junior, wajib cobain
# [2196] → Aspek: Kualitas Kopi | Keywords: susu triple peach americano, cafe malt latte, best banget, duo favoritku
# [2197] → Aspek: Menu Lain | Keywords: praline, gula
# [2198] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain; Promo | Keywords: rata2 enak bgttt, butterscotch seasalt cafe malt latte, buttercream latte; diskon 50; butterscotch seasalt cafe malt latte, buttercream latte; butuh diskon 50, fore dm testimoni profile
# [2199] → Aspek: Menu Lain | Keywords: butterscotch, buttercream, fore, beli
# [2200] → Aspek: Kualitas Kopi | Keywords: enak, creamy, sweet, manis, pass banget
# — Saved checkpoint at tweet #2200
# [2201] → Aspek: Kualitas Kopi | Keywords: enak, seger
# [2202] → Aspek: Kualitas Kopi | Keywords: kerasa, kopinya
# [2203] → Aspek: Menu Lain | Keywords: buttercream latte non coffee, darkchocoseasalt cream fore junior, choco caramel cloud, peach americano, bnyak urutannya gini, bosen butterscotch
# [2204] → Aspek: Menu Lain | Keywords: cafe malt latte, ganti menunya, irish latte, khas banget fore, inget banget
# [2205] → Aspek: Suasana/Tempat | Keywords: fore ambon, pengen
# [2206] → Aspek: Kualitas Kopi | Keywords: fore junior, enak
# [2207] → Aspek: Menu Lain; Promo | Keywords: fore junior milk butterschot, gapake kopi, manissss, sukakkkkk; free sticker
# [2208] → Aspek: Promo | Keywords: voucher, beli 1 gratis 1, app, tanggal 25
# [2209] → Aspek: Menu Lain | Keywords: blueberry muffin
# [2210] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #2210
# [2211] → Aspek: Kualitas Kopi | Keywords: fore, ma, nyushi
# [2212] → Aspek:  | Keywords:
# [2213] → Aspek: Harga/Nilai; Menu Lain; Promo | Keywords: voucher full, min sebulan, min 30; chatime, tawan, marugame; download app, nunjukin ktp, voucher full, min sebulan, min 30
# [2214] → Aspek: Promo | Keywords: minim 3 voucher
# [2215] → Aspek: Promo | Keywords: transaksi 30 akunnya aktif, birthday threatnya fore (kemungkinan besar maksudnya "birthday treat/promo")
# [2216] → Aspek: Layanan Pelanggan | Keywords: pesen, kasih, komplain
# [2217] → Aspek: Menu Lain | Keywords: banana cake, butter croissant, pain au choco, toko pastry, suka, fore
# [2218] → Aspek: Harga/Nilai; Promo | Keywords: isu bohong, tuku; isu bohong, tuku
# [2219] → Aspek: Menu Lain | Keywords: susu jahe
# [2220] → Aspek: Suasana/Tempat | Keywords: deket pintu tol
# — Saved checkpoint at tweet #2220
# [2221] → Aspek: Layanan Pelanggan | Keywords: nama panggilan, mas agil
# [2222] → Aspek: Menu Lain | Keywords: fore triple peach americano, kopi kenangan, oatside
# [2223] → Aspek: Layanan Pelanggan | Keywords: pesen, nama karina, pas nyampe, pesanan nama lily, masnya, udah pas
# [2224] → Aspek: Kualitas Kopi; Menu Lain | Keywords: tuku, fore, point coffee, coffee stuja, uncle jo, coffee coffee, goodday freeze; goodday freeze, abc susu
# [2225] → Aspek: Menu Lain | Keywords: calf fore, tuku, point coffee
# [2226] → Aspek: Kualitas Kopi | Keywords: kopi bikin hah, kopi seenak, lewatttttt
# [2227] → Aspek: Layanan Pelanggan; Menu Lain | Keywords: mas2nya, teriak manggil, bilang, kak jungkook; aren latte, large, gula sadar
# [2228] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: mantap; tuku, mantap
# [2229] → Aspek: Kualitas Kopi; Menu Lain | Keywords: butterscotch, mirip, kaya fore; butterscotch, fore
# [2230] → Aspek: Kualitas Kopi | Keywords: fore, series, tani
# — Saved checkpoint at tweet #2230
# [2231] → Aspek: Kualitas Kopi | Keywords: dominan creamy, kopinya tipis, extra shot, kopinya dominan, susu nya dominan
# [2232] → Aspek: Promo | Keywords: gift, tukuu
# [2233] → Aspek: Kualitas Kopi; Harga/Nilai | Keywords: enak, creamy, kopi kaneki, fore, calf, kopi jefersonnya; literan
# [2234] → Aspek: Kualitas Kopi | Keywords: suka kopi, selera, enak, foretuku
# [2235] → Aspek: Suasana/Tempat | Keywords: mirip2 fore
# [2236] → Aspek:  | Keywords:
# [2237] → Aspek: Suasana/Tempat | Keywords: calf fore
# [2238] → Aspek: Kualitas Kopi | Keywords: kopi
# [2239] → Aspek:  | Keywords:
# [2240] → Aspek: Harga/Nilai; Promo | Keywords: murah; app
# — Saved checkpoint at tweet #2240
# [2241] → Aspek: Kualitas Kopi | Keywords: fore, enak
# [2242] → Aspek:  | Keywords:
# [2243] → Aspek:  | Keywords:
# [2244] → Aspek:  | Keywords:
# [2245] → Aspek:  | Keywords:
# [2246] → Aspek: Layanan Pelanggan | Keywords: pegawai fore, dipanggil, pakai mic, nama justin bieber
# [2247] → Aspek: Kualitas Kopi | Keywords: fore calf, oke, kyknya
# [2248] → Aspek: Kualitas Kopi | Keywords: calf fore, tuku, enak
# [2249] → Aspek: Kualitas Kopi | Keywords: enak banget
# [2250] → Aspek:  | Keywords:
# — Saved checkpoint at tweet #2250
# [2251] → Aspek:  | Keywords:
# [2252] → Aspek: Kualitas Kopi; Menu Lain | Keywords: butterscotch, enak, enakan, point coffee, fore; butterscotch, menu, oatside
# [2253] → Aspek: Kualitas Kopi | Keywords: kopi, proper
# [2254] → Aspek: Suasana/Tempat | Keywords: point coffee, coffee fore, favorit, bgtt
# [2255] → Aspek: Kualitas Kopi; Harga/Nilai; Menu Lain; Promo | Keywords: matchanya, fore sih kak; diskonnya; matchanya; diskonnya, kopi kenangan shopee
# [2256] → Aspek: Kualitas Kopi | Keywords: menu kopinya, strong, gak strong
# [2257] → Aspek: Kualitas Kopi; Menu Lain | Keywords: gk strong, menu fore signature, tani series, kopi tani, tomoro better, kopi gojo, lumayan enakk; matcha, matcha megumi, enak banget
# [2258] → Aspek: Kualitas Kopi | Keywords: enak, strong banget, espresso
# [2259] → Aspek: Kualitas Kopi | Keywords: strong, fore
# [2260] → Aspek: Kualitas Kopi | Keywords: kopinya, tipis
# — Saved checkpoint at tweet #2260
# [2261] → Aspek: Kualitas Kopi | Keywords: enak, pait
# [2262] → Aspek: Menu Lain | Keywords: kopi kenangan, fore, buttercream tiramisu latte
# [2263] → Aspek: Kualitas Kopi | Keywords: enakan
# [2264] → Aspek: Kualitas Kopi; Menu Lain | Keywords: enakan, butterscotch; butterscotch nya
# [2265] → Aspek: Harga/Nilai | Keywords: harga, beda
# [2266] → Aspek: Harga/Nilai | Keywords: murahnya, versi murahnya
# [2267] → Aspek: Promo | Keywords: stiker, melulu, kasih
# [2268] → Aspek: Menu Lain | Keywords: minuman, fore junior, non coffee, gula
# [2269] → Aspek: Layanan Pelanggan | Keywords: habis, kakak, pembelian, stok nya
# [2270] → Aspek: Menu Lain | Keywords: menu
# — Saved checkpoint at tweet #2270
# [2271] → Aspek: Menu Lain | Keywords: fore junior, upsize, pesen
# [2272] → Aspek: Menu Lain | Keywords: junior, stiker
# [2273] → Aspek: Kualitas Kopi; Promo | Keywords: fore, junior, mantap; stiker
# [2274] → Aspek: Menu Lain | Keywords: menu juniornya, enak
# [2275] → Aspek: Menu Lain | Keywords: fore, junior
# [2276] → Aspek: Layanan Pelanggan; Promo | Keywords: dikasi stiker; stiker
# ✅ Done. All predictions saved.

# %% [markdown]
# HANDLING IMBALANCED DATA

# %%
import pandas as pd
from sklearn.utils import resample

# Load dataset
df = pd.read_excel('tweet_with_predicted_aspect.xlsx', sheet_name='sample')  # Ganti nama file jika berbeda

# Cek distribusi awal
print("Distribusi Awal Aspek:")
print(df['Predicted_Aspect'].value_counts())

# Tentukan aspek yang tersedia
aspects = df['Predicted_Aspect'].unique()

# Hitung jumlah sampel tertinggi
max_count = df['Predicted_Aspect'].value_counts().max()

# Lakukan random oversampling per aspek
balanced_df = pd.DataFrame()

for aspect in aspects:
    subset = df[df['Predicted_Aspect'] == aspect]
    resampled_subset = resample(subset,
                                replace=True,
                                n_samples=max_count,
                                random_state=42)
    balanced_df = pd.concat([balanced_df, resampled_subset])

# Reset index
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Cek distribusi setelah balancing
print("\nDistribusi Setelah Balancing:")
print(balanced_df['Predicted_Aspect'].value_counts())

# Simpan dataset balanced
balanced_df.to_excel('balanced_aspect_dataset.xlsx', index=False)
print("\nDataset balanced berhasil disimpan sebagai 'balanced_aspect_dataset.xlsx'")
# Out:
# Distribusi Awal Aspek:
# Predicted_Aspect
# Produk     255
# Promosi     27
# Layanan     18
# Name: count, dtype: int64
#
# Distribusi Setelah Balancing:
# Predicted_Aspect
# Layanan    255
# Promosi    255
# Produk     255
# Name: count, dtype: int64
#
# Dataset balanced berhasil disimpan sebagai 'balanced_aspect_dataset.xlsx'

# %% [markdown]
# EVALUATION

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report

# Load dataset hasil labeling dan prediksi
df = pd.read_excel('balanced_aspect_dataset.xlsx', sheet_name='Sheet1')  # Pastikan file kamu sesuai

# Ambil kolom yang diperlukan
y_true = df['Valid_Aspect'].astype(str)  # Kolom yang berisi label sebenarnya
y_pred = df['Predicted_Aspect'].astype(str)

# Hitung akurasi keseluruhan
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy: {accuracy:.4f}')

# Hitung precision, recall, f1-score per kelas
precision, recall, f1, support = precision_recall_fscore_support(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi'])

# Tampilkan hasil per kelas
aspect_labels = ['Produk', 'Layanan', 'Promosi']
for idx, aspect in enumerate(aspect_labels):
    print(f'\nAspect: {aspect}')
    print(f'Precision: {precision[idx]:.4f}')
    print(f'Recall: {recall[idx]:.4f}')
    print(f'F1-Score: {f1[idx]:.4f}')
    print(f'Support: {support[idx]}')

# Tampilkan classification report lengkap
print('\nClassification Report:')
print(classification_report(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi']))

# Tampilkan confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi'])
print('\nConfusion Matrix:')
print(pd.DataFrame(cm, index=['Produk (True)', 'Layanan (True)', 'Promosi (True)'],
                   columns=['Produk (Pred)', 'Layanan (Pred)', 'Promosi (Pred)']))
# Out:
# Accuracy: 0.6340
#
# Aspect: Produk
# Precision: 0.9176
# Recall: 0.5120
# F1-Score: 0.6573
# Support: 457
#
# Aspect: Layanan
# Precision: 0.5333
# Recall: 0.7727
# F1-Score: 0.6311
# Support: 176
#
# Aspect: Promosi
# Precision: 0.4510
# Recall: 0.8712
# F1-Score: 0.5943
# Support: 132
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Produk       0.92      0.51      0.66       457
#      Layanan       0.53      0.77      0.63       176
#      Promosi       0.45      0.87      0.59       132
#
#     accuracy                           0.63       765
#    macro avg       0.63      0.72      0.63       765
# weighted avg       0.75      0.63      0.64       765
#
#
# Confusion Matrix:
#                 Produk (Pred)  Layanan (Pred)  Promosi (Pred)
# Produk (True)             234             103             120
# Layanan (True)             20             136              20
# Promosi (True)              1              16             115
