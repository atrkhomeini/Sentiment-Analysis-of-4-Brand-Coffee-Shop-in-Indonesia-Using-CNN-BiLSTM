# %% [markdown]
# ASPECT EXTRACTION

# %%
GEMINI_API_KEY = 'AIzaSyC-KEAl0h05JIsSPfR7zPH3ykMO2ioMMWA'

# %%
import pandas as pd
import google.generativeai as genai
import time
import json
import os

# %%
# Ensure the client and model are correctly initialized
client = genai.configure(api_key=GEMINI_API_KEY)

# Inisialisasi model Gemini
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
df = pd.read_excel('../data/data_valid/main_indobert_train.xlsx', sheet_name='data_test')
# Siapkan kolom hasil
if 'Predicted_Aspect' not in df.columns:
    df['Predicted_Aspect'] = ""
# Checkpoint file untuk progress
checkpoint_file = 'progress_checkpoint.json'

# %%
# Load progress jika ada
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, 'r') as f:
        progress = json.load(f)
    print("Checkpoint loaded.")
else:
    progress = {}

# Looping untuk Zero-Shot Classification
save_interval = 10  # Simpan setiap 10 tweet
counter = 0
# Out:
# Checkpoint loaded.

# %%
df
# Out:
#           Date                                               Text  \
# 0   2024-01-01  Tim matcha green tea sm classic milo setiap be...
# 1   2024-01-01  Nder, mo nanya dong kalo minuman yang coklat-c...
# 2   2024-01-01                                      Fore aplikasi
# 3   2024-01-01           hari ini lagi coba menu baru(?)nya fore.
# 4   2024-01-01  LOH INI ADMINE TA tp aku cocok di caramel pral...
# ..         ...                                                ...
# 452 2024-12-01  Eemang ga enak ih tomoro mah, pait.. mending fore
# 453 2024-12-01                         Fore jelas. Beda harga kak
# 454 2024-12-01  Kakah gue sukanya jajan kopi di fore, jadi dia...
# 455 2024-12-01          OKKKKK MENU YANG AKAN KUBELI KALO KE FORE
# 456 2024-12-01  Ih kemaren ak beli fore junior ga dapet stiker :(
#
#                                     Text Normalization Label_Bert  \
# 0    tim matcha green tea classic milo beli fore se...   positive
# 1                   minuman coklatcoklat fore enak yaa   negative
# 2                                        fore aplikasi   positive
# 3                               coba menu barunya fore   positive
# 4    loh admine ta cocok caramel praline frappe for...   positive
# ..                                                 ...        ...
# 452                eemang enak ih tomoro mah pait fore   negative
# 453                                fore beda harga kak   negative
# 454  kakah sukanya jajan kopi fore jajan fore stike...   positive
# 455                            okkkkk menu kubeli fore    neutral
# 456                         ih beli fore junior stiker    neutral
#
#     Predicted_Aspect
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 452
# 453
# 454
# 455
# 456
#
# [457 rows x 5 columns]

# %%
for idx, row in df.iterrows():
    tweet = row['Text']
    
    prompt = f"""
    Tweet: "{tweet}"
    Available Aspects: Produk, Layanan, Promosi.
    Question: Which aspect does the tweet talk about? Only answer one aspect: Produk, Layanan, or Promosi. Do not explain.
    """
    
    try:
        response = model.generate_content([prompt])
        aspect = response.text.strip()

        df.at[idx, 'Predicted_Aspect'] = aspect
        progress[str(idx)] = aspect  # Simpan progress
        counter += 1

        print(f"Processed tweet {idx+1}/{len(df)}: Aspect = {aspect}")

        # Simpan setiap N tweet
        if counter % save_interval == 0:
            with open(checkpoint_file, 'w') as f:
                json.dump(progress, f)
            df.to_excel('tweet_with_predicted_aspect_test.xlsx', index=False)
            print(f"Progress saved after {counter} tweets.")

        time.sleep(2.0)  # Hindari rate-limit

    except Exception as e:
        print(f"Error processing tweet {idx+1}: {e}")
        df.at[idx, 'Predicted_Aspect'] = 'ERROR'
        continue

# Simpan file akhir
with open(checkpoint_file, 'w') as f:
    json.dump(progress, f)
df.to_excel('tweet_with_predicted_aspect_test.xlsx', index=False)
print("Aspect prediction completed and final progress saved.")
# Out:
# Processed tweet 1/457: Aspect = Produk
# Processed tweet 2/457: Aspect = Produk
# Processed tweet 3/457: Aspect = Produk
# Processed tweet 4/457: Aspect = Produk
# Processed tweet 5/457: Aspect = Produk
# Processed tweet 6/457: Aspect = Produk
# Progress saved after 10 tweets.
# Processed tweet 7/457: Aspect = Produk
# Error processing tweet 8: Invalid operation: The `response.parts` quick accessor requires a single candidate, but but `response.candidates` is empty.
# This appears to be caused by a blocked prompt, see `response.prompt_feedback`: block_reason: PROHIBITED_CONTENT
#
# Processed tweet 9/457: Aspect = Produk
# Processed tweet 10/457: Aspect = Produk
# Processed tweet 11/457: Aspect = Produk
# Processed tweet 12/457: Aspect = Produk
# Processed tweet 13/457: Aspect = Layanan
# Processed tweet 14/457: Aspect = Produk
# Processed tweet 15/457: Aspect = Produk
# Processed tweet 16/457: Aspect = Produk
# Processed tweet 17/457: Aspect = Produk
# Progress saved after 20 tweets.
# Processed tweet 18/457: Aspect = Promosi
# Processed tweet 19/457: Aspect = Produk
# Processed tweet 20/457: Aspect = Produk
# Processed tweet 21/457: Aspect = Produk
# Processed tweet 22/457: Aspect = Produk
# Processed tweet 23/457: Aspect = Produk
# Processed tweet 24/457: Aspect = Promosi
# Processed tweet 25/457: Aspect = Produk
# Processed tweet 26/457: Aspect = Produk
# Processed tweet 27/457: Aspect = Produk
# Progress saved after 30 tweets.
# Processed tweet 28/457: Aspect = Promosi
# Processed tweet 29/457: Aspect = Produk
# Processed tweet 30/457: Aspect = Promosi
# Processed tweet 31/457: Aspect = Produk
# Processed tweet 32/457: Aspect = Produk
# Processed tweet 33/457: Aspect = Produk
# Processed tweet 34/457: Aspect = Produk
# Processed tweet 35/457: Aspect = Layanan
# Processed tweet 36/457: Aspect = Produk
# Processed tweet 37/457: Aspect = Produk
# Progress saved after 40 tweets.
# Processed tweet 38/457: Aspect = Produk
# Processed tweet 39/457: Aspect = Produk
# Processed tweet 40/457: Aspect = Produk
# Processed tweet 41/457: Aspect = Produk
# Processed tweet 42/457: Aspect = Layanan
# Processed tweet 43/457: Aspect = Produk
# Processed tweet 44/457: Aspect = Produk
# Processed tweet 45/457: Aspect = Layanan
# Processed tweet 46/457: Aspect = Produk
# Processed tweet 47/457: Aspect = Produk
# Progress saved after 50 tweets.
# Processed tweet 48/457: Aspect = Produk
# Processed tweet 49/457: Aspect = Produk
# Processed tweet 50/457: Aspect = Promosi
# Processed tweet 51/457: Aspect = Produk
# Processed tweet 52/457: Aspect = Produk
# Processed tweet 53/457: Aspect = Layanan
# Processed tweet 54/457: Aspect = Produk
# Processed tweet 55/457: Aspect = Produk
# Processed tweet 56/457: Aspect = Produk
# Processed tweet 57/457: Aspect = Produk
# Progress saved after 60 tweets.
# Processed tweet 58/457: Aspect = Produk
# Processed tweet 59/457: Aspect = Produk
# Processed tweet 60/457: Aspect = Produk
# Processed tweet 61/457: Aspect = Produk
# Processed tweet 62/457: Aspect = Produk
# Processed tweet 63/457: Aspect = Produk
# Processed tweet 64/457: Aspect = Produk
# Processed tweet 65/457: Aspect = Produk
# Processed tweet 66/457: Aspect = Produk
# Processed tweet 67/457: Aspect = Produk
# Progress saved after 70 tweets.
# Processed tweet 68/457: Aspect = Produk
# Processed tweet 69/457: Aspect = Produk
# Processed tweet 70/457: Aspect = Produk
# Processed tweet 71/457: Aspect = Produk
# Processed tweet 72/457: Aspect = Produk
# Processed tweet 73/457: Aspect = Produk
# Processed tweet 74/457: Aspect = Produk
# ```json
# "aspect": "Produk"
# ```
# Processed tweet 75/457: Aspect = Produk
# Processed tweet 76/457: Aspect = Produk
# Processed tweet 77/457: Aspect = Produk
# Progress saved after 80 tweets.
# Processed tweet 78/457: Aspect = Promosi
# Processed tweet 79/457: Aspect = Produk
# Processed tweet 80/457: Aspect = Produk
# Processed tweet 81/457: Aspect = Produk
# Processed tweet 82/457: Aspect = Produk
# Processed tweet 83/457: Aspect = Produk
# Processed tweet 84/457: Aspect = Produk
# Processed tweet 85/457: Aspect = Produk
# Processed tweet 86/457: Aspect = Produk
# Processed tweet 87/457: Aspect = Produk
# Progress saved after 90 tweets.
# Processed tweet 88/457: Aspect = Produk
# Processed tweet 89/457: Aspect = Produk
# Processed tweet 90/457: Aspect = Produk
# Processed tweet 91/457: Aspect = Produk
# Processed tweet 92/457: Aspect = Promosi
# Processed tweet 93/457: Aspect = Produk
# Processed tweet 94/457: Aspect = Produk
# Processed tweet 95/457: Aspect = Produk
# Processed tweet 96/457: Aspect = Produk
# Processed tweet 97/457: Aspect = Produk
# Progress saved after 100 tweets.
# Processed tweet 98/457: Aspect = Produk
# Processed tweet 99/457: Aspect = Layanan
# Processed tweet 100/457: Aspect = Produk
# Processed tweet 101/457: Aspect = Layanan
# Processed tweet 102/457: Aspect = Produk
# Processed tweet 103/457: Aspect = Produk
# Processed tweet 104/457: Aspect = Produk
# Processed tweet 105/457: Aspect = Produk
# Processed tweet 106/457: Aspect = Produk
# Processed tweet 107/457: Aspect = Produk
# Progress saved after 110 tweets.
# Processed tweet 108/457: Aspect = Produk
# Processed tweet 109/457: Aspect = Produk
# Processed tweet 110/457: Aspect = Produk
# Processed tweet 111/457: Aspect = Produk
# Processed tweet 112/457: Aspect = Produk
# Processed tweet 113/457: Aspect = Promosi
# Processed tweet 114/457: Aspect = Produk
# Processed tweet 115/457: Aspect = Produk
# Processed tweet 116/457: Aspect = Produk
# Processed tweet 117/457: Aspect = Produk
# Progress saved after 120 tweets.
# Processed tweet 118/457: Aspect = Produk
# Processed tweet 119/457: Aspect = Produk
# Processed tweet 120/457: Aspect = Produk
# Processed tweet 121/457: Aspect = Produk
# Processed tweet 122/457: Aspect = Produk
# Processed tweet 123/457: Aspect = Produk
# Processed tweet 124/457: Aspect = Produk
# Processed tweet 125/457: Aspect = Promosi
# Processed tweet 126/457: Aspect = Produk
# Processed tweet 127/457: Aspect = Produk
# Progress saved after 130 tweets.
# Processed tweet 128/457: Aspect = Produk
# Processed tweet 129/457: Aspect = Produk
# Processed tweet 130/457: Aspect = Produk
# Processed tweet 131/457: Aspect = Produk
# Processed tweet 132/457: Aspect = Produk
# Processed tweet 133/457: Aspect = Produk
# Processed tweet 134/457: Aspect = Produk
# Processed tweet 135/457: Aspect = Produk
# Processed tweet 136/457: Aspect = Produk
# Processed tweet 137/457: Aspect = Produk
# Progress saved after 140 tweets.
# Processed tweet 138/457: Aspect = Produk
# Processed tweet 139/457: Aspect = Produk
# Processed tweet 140/457: Aspect = Produk
# Processed tweet 141/457: Aspect = Produk
# Processed tweet 142/457: Aspect = Layanan
# Processed tweet 143/457: Aspect = Produk
# Processed tweet 144/457: Aspect = Produk
# Processed tweet 145/457: Aspect = Produk
# Processed tweet 146/457: Aspect = Produk
# Processed tweet 147/457: Aspect = Produk
# Progress saved after 150 tweets.
# Processed tweet 148/457: Aspect = Produk
# Processed tweet 149/457: Aspect = Produk
# Processed tweet 150/457: Aspect = Layanan
# Processed tweet 151/457: Aspect = Produk
# Processed tweet 152/457: Aspect = Produk
# Processed tweet 153/457: Aspect = Produk
# Processed tweet 154/457: Aspect = Produk
# Processed tweet 155/457: Aspect = Produk
# Processed tweet 156/457: Aspect = Layanan
# Processed tweet 157/457: Aspect = Produk
# Progress saved after 160 tweets.
# Processed tweet 158/457: Aspect = Produk
# Processed tweet 159/457: Aspect = Produk
# Processed tweet 160/457: Aspect = Produk
# Processed tweet 161/457: Aspect = Produk
# Processed tweet 162/457: Aspect = Produk
# Processed tweet 163/457: Aspect = Produk
# Processed tweet 164/457: Aspect = Produk
# Processed tweet 165/457: Aspect = Promosi
# Processed tweet 166/457: Aspect = Produk
# Processed tweet 167/457: Aspect = Produk
# Progress saved after 170 tweets.
# Processed tweet 168/457: Aspect = Produk
# Processed tweet 169/457: Aspect = Layanan
# Processed tweet 170/457: Aspect = Produk
# Processed tweet 171/457: Aspect = Produk
# Processed tweet 172/457: Aspect = Produk
# Processed tweet 173/457: Aspect = Produk
# Processed tweet 174/457: Aspect = Promosi
# Processed tweet 175/457: Aspect = Promosi
# Processed tweet 176/457: Aspect = Produk
# Processed tweet 177/457: Aspect = Produk
# Progress saved after 180 tweets.
# Processed tweet 178/457: Aspect = Produk
# Processed tweet 179/457: Aspect = Produk
# Processed tweet 180/457: Aspect = Produk
# Processed tweet 181/457: Aspect = Promosi
# Processed tweet 182/457: Aspect = Produk
# Processed tweet 183/457: Aspect = Produk
# Processed tweet 184/457: Aspect = Produk
# Processed tweet 185/457: Aspect = Produk
# Processed tweet 186/457: Aspect = Produk
# Processed tweet 187/457: Aspect = Produk
# Progress saved after 190 tweets.
# Processed tweet 188/457: Aspect = Produk
# Processed tweet 189/457: Aspect = Produk
# Processed tweet 190/457: Aspect = Produk
# Processed tweet 191/457: Aspect = Produk
# Processed tweet 192/457: Aspect = Produk
# Processed tweet 193/457: Aspect = Produk
# Processed tweet 194/457: Aspect = Produk
# Processed tweet 195/457: Aspect = Produk
# Processed tweet 196/457: Aspect = Produk
# Processed tweet 197/457: Aspect = Promosi
# Progress saved after 200 tweets.
# Processed tweet 198/457: Aspect = Produk
# Processed tweet 199/457: Aspect = Promosi
# Processed tweet 200/457: Aspect = Produk
# Processed tweet 201/457: Aspect = Produk
# Processed tweet 202/457: Aspect = Promosi
# Processed tweet 203/457: Aspect = Promosi
# Processed tweet 204/457: Aspect = Produk
# Processed tweet 205/457: Aspect = Produk
# Processed tweet 206/457: Aspect = Promosi
# Processed tweet 207/457: Aspect = Produk
# Progress saved after 210 tweets.
# Processed tweet 208/457: Aspect = Produk
# Processed tweet 209/457: Aspect = Produk
# Processed tweet 210/457: Aspect = Produk
# Processed tweet 211/457: Aspect = Produk
# Processed tweet 212/457: Aspect = Produk
# Processed tweet 213/457: Aspect = Promosi
# Processed tweet 214/457: Aspect = Produk
# Processed tweet 215/457: Aspect = Produk
# Processed tweet 216/457: Aspect = Produk
# Processed tweet 217/457: Aspect = Produk
# Progress saved after 220 tweets.
# Processed tweet 218/457: Aspect = Layanan
# Processed tweet 219/457: Aspect = Produk
# Processed tweet 220/457: Aspect = Produk
# Processed tweet 221/457: Aspect = Produk
# Processed tweet 222/457: Aspect = Produk
# Processed tweet 223/457: Aspect = Produk
# Processed tweet 224/457: Aspect = Produk
# Processed tweet 225/457: Aspect = Produk
# Processed tweet 226/457: Aspect = Produk
# Processed tweet 227/457: Aspect = Produk
# Progress saved after 230 tweets.
# Processed tweet 228/457: Aspect = Produk
# Processed tweet 229/457: Aspect = Layanan
# Processed tweet 230/457: Aspect = Produk
# Processed tweet 231/457: Aspect = Produk
# Processed tweet 232/457: Aspect = Produk
# Processed tweet 233/457: Aspect = Produk
# Processed tweet 234/457: Aspect = Produk
# Processed tweet 235/457: Aspect = Produk
# Processed tweet 236/457: Aspect = Produk
# Processed tweet 237/457: Aspect = Produk
# Progress saved after 240 tweets.
# Processed tweet 238/457: Aspect = Produk
# Processed tweet 239/457: Aspect = Produk
# Processed tweet 240/457: Aspect = Layanan
# Processed tweet 241/457: Aspect = Promosi
# Processed tweet 242/457: Aspect = Produk
# Processed tweet 243/457: Aspect = Produk
# Processed tweet 244/457: Aspect = Promosi
# Processed tweet 245/457: Aspect = Produk
# Processed tweet 246/457: Aspect = Layanan
# Processed tweet 247/457: Aspect = Promosi
# Progress saved after 250 tweets.
# Processed tweet 248/457: Aspect = Produk
# Processed tweet 249/457: Aspect = Produk
# Processed tweet 250/457: Aspect = Produk
# Processed tweet 251/457: Aspect = Layanan
# Processed tweet 252/457: Aspect = Promosi
# Processed tweet 253/457: Aspect = Layanan
# Processed tweet 254/457: Aspect = Promosi
# Processed tweet 255/457: Aspect = Produk
# Processed tweet 256/457: Aspect = Produk
# Processed tweet 257/457: Aspect = Produk
# Progress saved after 260 tweets.
# Processed tweet 258/457: Aspect = Layanan
# Processed tweet 259/457: Aspect = Produk
# Processed tweet 260/457: Aspect = Produk
# Processed tweet 261/457: Aspect = Produk
# Processed tweet 262/457: Aspect = Produk
# Processed tweet 263/457: Aspect = Produk
# Processed tweet 264/457: Aspect = Produk
# Processed tweet 265/457: Aspect = Produk
# Processed tweet 266/457: Aspect = Produk
# Processed tweet 267/457: Aspect = Layanan
# Progress saved after 270 tweets.
# Processed tweet 268/457: Aspect = Produk
# Processed tweet 269/457: Aspect = Produk
# Processed tweet 270/457: Aspect = Produk
# Processed tweet 271/457: Aspect = Produk
# Processed tweet 272/457: Aspect = Produk
# Processed tweet 273/457: Aspect = Produk
# Processed tweet 274/457: Aspect = Produk
# Processed tweet 275/457: Aspect = Promosi
# Processed tweet 276/457: Aspect = Produk
# Processed tweet 277/457: Aspect = Produk
# Progress saved after 280 tweets.
# Processed tweet 278/457: Aspect = Produk
# Processed tweet 279/457: Aspect = Produk
# Processed tweet 280/457: Aspect = Produk
# Processed tweet 281/457: Aspect = Produk
# Processed tweet 282/457: Aspect = Produk
# Processed tweet 283/457: Aspect = Produk
# Processed tweet 284/457: Aspect = Produk
# Processed tweet 285/457: Aspect = Produk
# Processed tweet 286/457: Aspect = Produk
# Processed tweet 287/457: Aspect = Produk
# Progress saved after 290 tweets.
# Processed tweet 288/457: Aspect = Produk
# Processed tweet 289/457: Aspect = Produk
# Processed tweet 290/457: Aspect = Produk
# Processed tweet 291/457: Aspect = Produk
# Processed tweet 292/457: Aspect = Produk
# Processed tweet 293/457: Aspect = Produk
# Processed tweet 294/457: Aspect = Produk
# Processed tweet 295/457: Aspect = Produk
# Processed tweet 296/457: Aspect = Promosi
# Processed tweet 297/457: Aspect = Produk
# Progress saved after 300 tweets.
# Processed tweet 298/457: Aspect = Produk
# Processed tweet 299/457: Aspect = Produk
# Processed tweet 300/457: Aspect = Produk
# Processed tweet 301/457: Aspect = Produk
# Processed tweet 302/457: Aspect = Produk
# Processed tweet 303/457: Aspect = Produk
# Processed tweet 304/457: Aspect = Produk
# Processed tweet 305/457: Aspect = Produk
# Processed tweet 306/457: Aspect = Produk
# Processed tweet 307/457: Aspect = Produk
# Progress saved after 310 tweets.
# Processed tweet 308/457: Aspect = Produk
# Processed tweet 309/457: Aspect = Produk
# Processed tweet 310/457: Aspect = Produk
# Processed tweet 311/457: Aspect = Produk
# Processed tweet 312/457: Aspect = Promosi
# Processed tweet 313/457: Aspect = Produk
# Processed tweet 314/457: Aspect = Produk
# Processed tweet 315/457: Aspect = Produk
# Processed tweet 316/457: Aspect = Promosi
# Processed tweet 317/457: Aspect = Promosi
# Progress saved after 320 tweets.
# Processed tweet 318/457: Aspect = Produk
# Processed tweet 319/457: Aspect = Produk
# Processed tweet 320/457: Aspect = Produk
# Processed tweet 321/457: Aspect = Promosi
# Processed tweet 322/457: Aspect = Produk
# Processed tweet 323/457: Aspect = Produk
# Processed tweet 324/457: Aspect = Produk
# Processed tweet 325/457: Aspect = Layanan
# Processed tweet 326/457: Aspect = Produk
# Processed tweet 327/457: Aspect = Produk
# Progress saved after 330 tweets.
# Processed tweet 328/457: Aspect = Produk
# Processed tweet 329/457: Aspect = Produk
# Processed tweet 330/457: Aspect = Produk
# Processed tweet 331/457: Aspect = Produk
# Processed tweet 332/457: Aspect = Produk
# Processed tweet 333/457: Aspect = Produk
# Processed tweet 334/457: Aspect = Produk
# Processed tweet 335/457: Aspect = Produk
# Processed tweet 336/457: Aspect = Produk
# Processed tweet 337/457: Aspect = Produk
# Progress saved after 340 tweets.
# Processed tweet 338/457: Aspect = Produk
# Processed tweet 339/457: Aspect = Produk
# Processed tweet 340/457: Aspect = Produk
# Processed tweet 341/457: Aspect = Promosi
# Processed tweet 342/457: Aspect = Produk
# Processed tweet 343/457: Aspect = Produk
# Processed tweet 344/457: Aspect = Produk
# Processed tweet 345/457: Aspect = Produk
# Processed tweet 346/457: Aspect = Produk
# Processed tweet 347/457: Aspect = Produk
# Progress saved after 350 tweets.
# Processed tweet 348/457: Aspect = Produk
# Processed tweet 349/457: Aspect = Promosi
# Processed tweet 350/457: Aspect = Produk
# Processed tweet 351/457: Aspect = Produk
# Processed tweet 352/457: Aspect = Layanan
# Processed tweet 353/457: Aspect = Layanan
# Processed tweet 354/457: Aspect = Produk
# Processed tweet 355/457: Aspect = Produk
# Processed tweet 356/457: Aspect = Produk
# Processed tweet 357/457: Aspect = Produk
# Progress saved after 360 tweets.
# Processed tweet 358/457: Aspect = Layanan
# Processed tweet 359/457: Aspect = Produk
# Processed tweet 360/457: Aspect = Produk
# Processed tweet 361/457: Aspect = Produk
# Processed tweet 362/457: Aspect = Produk
# Processed tweet 363/457: Aspect = Layanan
# Processed tweet 364/457: Aspect = Produk
# Processed tweet 365/457: Aspect = Produk
# Processed tweet 366/457: Aspect = Produk
# Processed tweet 367/457: Aspect = Produk
# Progress saved after 370 tweets.
# Processed tweet 368/457: Aspect = Produk
# Processed tweet 369/457: Aspect = Produk
# Processed tweet 370/457: Aspect = Produk
# Processed tweet 371/457: Aspect = Promosi
# Processed tweet 372/457: Aspect = Produk
# Processed tweet 373/457: Aspect = Produk
# Processed tweet 374/457: Aspect = Produk
# Processed tweet 375/457: Aspect = Produk
# Processed tweet 376/457: Aspect = Produk
# Processed tweet 377/457: Aspect = Promosi
# Progress saved after 380 tweets.
# Processed tweet 378/457: Aspect = Produk
# Processed tweet 379/457: Aspect = Produk
# Processed tweet 380/457: Aspect = Layanan
# Processed tweet 381/457: Aspect = Produk
# Processed tweet 382/457: Aspect = Produk
# Processed tweet 383/457: Aspect = Produk
# Processed tweet 384/457: Aspect = Produk
# Processed tweet 385/457: Aspect = Produk
# Processed tweet 386/457: Aspect = Produk
# Processed tweet 387/457: Aspect = Produk
# Progress saved after 390 tweets.
# Processed tweet 388/457: Aspect = Produk
# Processed tweet 389/457: Aspect = Produk
# Processed tweet 390/457: Aspect = Produk
# Processed tweet 391/457: Aspect = Promosi
# Processed tweet 392/457: Aspect = Produk
# Processed tweet 393/457: Aspect = Produk
# Processed tweet 394/457: Aspect = Promosi
# Processed tweet 395/457: Aspect = Produk
# Processed tweet 396/457: Aspect = Promosi
# Processed tweet 397/457: Aspect = Produk
# Progress saved after 400 tweets.
# Processed tweet 398/457: Aspect = Layanan
# Processed tweet 399/457: Aspect = Produk
# Processed tweet 400/457: Aspect = Promosi
# Processed tweet 401/457: Aspect = Produk
# Processed tweet 402/457: Aspect = Produk
# Processed tweet 403/457: Aspect = Promosi
# Processed tweet 404/457: Aspect = Produk
# Processed tweet 405/457: Aspect = Produk
# Processed tweet 406/457: Aspect = Produk
# Processed tweet 407/457: Aspect = Produk
# Progress saved after 410 tweets.
# Processed tweet 408/457: Aspect = Produk
# Processed tweet 409/457: Aspect = Produk
# Processed tweet 410/457: Aspect = Produk
# Processed tweet 411/457: Aspect = Promosi
# Processed tweet 412/457: Aspect = Produk
# Processed tweet 413/457: Aspect = Promosi
# Processed tweet 414/457: Aspect = Promosi
# Processed tweet 415/457: Aspect = Produk
# Processed tweet 416/457: Aspect = Layanan
# Processed tweet 417/457: Aspect = Produk
# Progress saved after 420 tweets.
# Processed tweet 418/457: Aspect = Produk
# Processed tweet 419/457: Aspect = Promosi
# Processed tweet 420/457: Aspect = Produk
# Processed tweet 421/457: Aspect = Produk
# Processed tweet 422/457: Aspect = Produk
# Processed tweet 423/457: Aspect = Produk
# Processed tweet 424/457: Aspect = Produk
# Processed tweet 425/457: Aspect = Produk
# Processed tweet 426/457: Aspect = Produk
# Processed tweet 427/457: Aspect = Produk
# Progress saved after 430 tweets.
# Processed tweet 428/457: Aspect = Produk
# Processed tweet 429/457: Aspect = Produk
# Processed tweet 430/457: Aspect = Produk
# Processed tweet 431/457: Aspect = Produk
# Processed tweet 432/457: Aspect = Produk
# Processed tweet 433/457: Aspect = Produk
# Processed tweet 434/457: Aspect = Produk
# Processed tweet 435/457: Aspect = Produk
# Processed tweet 436/457: Aspect = Produk
# Processed tweet 437/457: Aspect = Layanan
# Progress saved after 440 tweets.
# Processed tweet 438/457: Aspect = Produk
# Processed tweet 439/457: Aspect = Promosi
# Processed tweet 440/457: Aspect = Promosi
# Processed tweet 441/457: Aspect = Produk
# Processed tweet 442/457: Aspect = Produk
# Processed tweet 443/457: Aspect = Produk
# Processed tweet 444/457: Aspect = Promosi
# Processed tweet 445/457: Aspect = Produk
# Processed tweet 446/457: Aspect = Produk
# Processed tweet 447/457: Aspect = Layanan
# Progress saved after 450 tweets.
# Processed tweet 448/457: Aspect = Produk
# Processed tweet 449/457: Aspect = Produk
# Processed tweet 450/457: Aspect = Promosi
# Processed tweet 451/457: Aspect = Produk
# Processed tweet 452/457: Aspect = Produk
# Processed tweet 453/457: Aspect = Produk
# Processed tweet 454/457: Aspect = Produk
# Processed tweet 455/457: Aspect = Promosi
# Processed tweet 456/457: Aspect = Produk
# Processed tweet 457/457: Aspect = Promosi
# Progress saved after 460 tweets.
# Aspect prediction completed and final progress saved.

# %% [markdown]
# HANDLING IMBALANCED DATA

# %%
import pandas as pd
from sklearn.utils import resample

# Load dataset
df = pd.read_excel('tweet_with_predicted_aspect.xlsx', sheet_name='sample')  # Ganti nama file jika berbeda

# Cek distribusi awal
print("Distribusi Awal Aspek:")
print(df['Predicted_Aspect'].value_counts())

# Tentukan aspek yang tersedia
aspects = df['Predicted_Aspect'].unique()

# Hitung jumlah sampel tertinggi
max_count = df['Predicted_Aspect'].value_counts().max()

# Lakukan random oversampling per aspek
balanced_df = pd.DataFrame()

for aspect in aspects:
    subset = df[df['Predicted_Aspect'] == aspect]
    resampled_subset = resample(subset,
                                replace=True,
                                n_samples=max_count,
                                random_state=42)
    balanced_df = pd.concat([balanced_df, resampled_subset])

# Reset index
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Cek distribusi setelah balancing
print("\nDistribusi Setelah Balancing:")
print(balanced_df['Predicted_Aspect'].value_counts())

# Simpan dataset balanced
balanced_df.to_excel('balanced_aspect_dataset.xlsx', index=False)
print("\nDataset balanced berhasil disimpan sebagai 'balanced_aspect_dataset.xlsx'")
# Out:
# Distribusi Awal Aspek:
# Predicted_Aspect
# Produk     255
# Promosi     27
# Layanan     18
# Name: count, dtype: int64
#
# Distribusi Setelah Balancing:
# Predicted_Aspect
# Layanan    255
# Promosi    255
# Produk     255
# Name: count, dtype: int64
#
# Dataset balanced berhasil disimpan sebagai 'balanced_aspect_dataset.xlsx'

# %% [markdown]
# EVALUATION

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report

# Load dataset hasil labeling dan prediksi
df = pd.read_excel('balanced_aspect_dataset.xlsx', sheet_name='Sheet1')  # Pastikan file kamu sesuai

# Ambil kolom yang diperlukan
y_true = df['Valid_Aspect'].astype(str)  # Kolom yang berisi label sebenarnya
y_pred = df['Predicted_Aspect'].astype(str)

# Hitung akurasi keseluruhan
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy: {accuracy:.4f}')

# Hitung precision, recall, f1-score per kelas
precision, recall, f1, support = precision_recall_fscore_support(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi'])

# Tampilkan hasil per kelas
aspect_labels = ['Produk', 'Layanan', 'Promosi']
for idx, aspect in enumerate(aspect_labels):
    print(f'\nAspect: {aspect}')
    print(f'Precision: {precision[idx]:.4f}')
    print(f'Recall: {recall[idx]:.4f}')
    print(f'F1-Score: {f1[idx]:.4f}')
    print(f'Support: {support[idx]}')

# Tampilkan classification report lengkap
print('\nClassification Report:')
print(classification_report(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi']))

# Tampilkan confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=['Produk', 'Layanan', 'Promosi'])
print('\nConfusion Matrix:')
print(pd.DataFrame(cm, index=['Produk (True)', 'Layanan (True)', 'Promosi (True)'],
                   columns=['Produk (Pred)', 'Layanan (Pred)', 'Promosi (Pred)']))
# Out:
# Accuracy: 0.6340
#
# Aspect: Produk
# Precision: 0.9176
# Recall: 0.5120
# F1-Score: 0.6573
# Support: 457
#
# Aspect: Layanan
# Precision: 0.5333
# Recall: 0.7727
# F1-Score: 0.6311
# Support: 176
#
# Aspect: Promosi
# Precision: 0.4510
# Recall: 0.8712
# F1-Score: 0.5943
# Support: 132
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Produk       0.92      0.51      0.66       457
#      Layanan       0.53      0.77      0.63       176
#      Promosi       0.45      0.87      0.59       132
#
#     accuracy                           0.63       765
#    macro avg       0.63      0.72      0.63       765
# weighted avg       0.75      0.63      0.64       765
#
#
# Confusion Matrix:
#                 Produk (Pred)  Layanan (Pred)  Promosi (Pred)
# Produk (True)             234             103             120
# Layanan (True)             20             136              20
# Promosi (True)              1              16             115
